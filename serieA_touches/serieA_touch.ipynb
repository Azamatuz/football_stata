# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

sns.palplot(sns.color_palette('deep'))


# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
# Font Imports

import matplotlib.font_manager as fm
heading_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/PlayfairDisplay-Regular.ttf', size=28)
subtitle_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/Roboto-Regular.ttf', size=18)
lable_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/Roboto-Regular.ttf', size=20)

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

# %%
df_touch = pd.read_csv('touch.csv', header=1)
df_touch = df_touch.fillna(0)

df_touch.tail()
# Out:
#         Squad  # Pl  Poss  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  \
# 15  Sampdoria    31  42.4    20183     2404     6584     9410     5492
# 16   Sassuolo    31  57.8    26144     2695     8001    13298     6689
# 17       SPAL    34  46.8    21112     2804     7530     9811     5115
# 18     Torino    27  47.5    21006     2680     7614     9564     5246
# 19    Udinese    25  44.7    21038     2619     7642     9704     5094
#
#     Att Pen   Live  Succ  Att  Succ%  #Pl  Megs  Carries  TotDist  PrgDist  \
# 15      776  18350   349  570   61.2  365    24    12230    73038    40477
# 16      948  24344   511  795   64.3  546    35    18372   109566    64497
# 17      706  19253   393  605   65.0  414    20    13430    80927    44155
# 18      833  19100   496  783   63.3  529    15    13063    84966    47283
# 19      793  19331   365  608   60.0  394    18    13363    83422    47368
#
#      Targ    Rec  Rec%  Miscon  Dispos
# 15  14468  12021  83.1     386     382
# ...

# %%
df_touch['Def Pen'].values
# Out:
# array([2038, 2524, 2728, 2763, 2399, 2972, 2507, 2662, 2192, 2634, 2985,
#        2452, 2339, 2935, 2441, 2404, 2695, 2804, 2680, 2619])

# %%
d = {'Val':df_touch['Def Pen'].values, 'Total':df_touch['Touches'].values,'Squad': df_touch['Squad'].values, 'Zone': 'Def Pen'}
Def_Pen = pd.DataFrame(data=d)

Def_Pen
# Out:
#      Val  Total          Squad     Zone
# 0   2038  26357       Atalanta  Def Pen
# 1   2524  22942        Bologna  Def Pen
# 2   2728  19036        Brescia  Def Pen
# 3   2763  21166       Cagliari  Def Pen
# 4   2399  21656     Fiorentina  Def Pen
# 5   2972  22396          Genoa  Def Pen
# 6   2507  21760  Hellas Verona  Def Pen
# 7   2662  24871          Inter  Def Pen
# 8   2192  27689       Juventus  Def Pen
# 9   2634  23467          Lazio  Def Pen
# 10  2985  21337          Lecce  Def Pen
# 11  2452  25056          Milan  Def Pen
# 12  2339  28332         Napoli  Def Pen
# 13  2935  20215          Parma  Def Pen
# 14  2441  23491           Roma  Def Pen
# 15  2404  20183      Sampdoria  Def Pen
# 16  2695  26144       Sassuolo  Def Pen
# 17  2804  21112           SPAL  Def Pen
# 18  2680  21006         Torino  Def Pen
# 19  2619  21038        Udinese  Def Pen

# %%
d = {'Val':df_touch['Def 3rd'].values, 'Total':df_touch['Touches'].values,'Squad': df_touch['Squad'].values, 'Zone': 'Def 3rd'}
Def_3rd = pd.DataFrame(data=d)

Def_3rd
# Out:
#      Val  Total          Squad     Zone
# 0   7049  26357       Atalanta  Def 3rd
# 1   7206  22942        Bologna  Def 3rd
# 2   7370  19036        Brescia  Def 3rd
# 3   7688  21166       Cagliari  Def 3rd
# 4   7027  21656     Fiorentina  Def 3rd
# 5   8104  22396          Genoa  Def 3rd
# 6   6777  21760  Hellas Verona  Def 3rd
# 7   7964  24871          Inter  Def 3rd
# 8   6983  27689       Juventus  Def 3rd
# 9   7646  23467          Lazio  Def 3rd
# 10  8158  21337          Lecce  Def 3rd
# 11  7401  25056          Milan  Def 3rd
# 12  7684  28332         Napoli  Def 3rd
# 13  7596  20215          Parma  Def 3rd
# 14  7217  23491           Roma  Def 3rd
# 15  6584  20183      Sampdoria  Def 3rd
# 16  8001  26144       Sassuolo  Def 3rd
# 17  7530  21112           SPAL  Def 3rd
# 18  7614  21006         Torino  Def 3rd
# 19  7642  21038        Udinese  Def 3rd

# %%
d = {'Val':df_touch['Mid 3rd'].values,  'Total':df_touch['Touches'].values, 'Squad': df_touch['Squad'].values, 'Zone': 'Mid 3rd'}
Mid_3rd = pd.DataFrame(data=d)

Mid_3rd
# Out:
#       Val  Total          Squad     Zone
# 0   12944  26357       Atalanta  Mid 3rd
# 1   10874  22942        Bologna  Mid 3rd
# 2    8129  19036        Brescia  Mid 3rd
# 3    9811  21166       Cagliari  Mid 3rd
# 4   10271  21656     Fiorentina  Mid 3rd
# 5   10344  22396          Genoa  Mid 3rd
# 6   10796  21760  Hellas Verona  Mid 3rd
# 7   11912  24871          Inter  Mid 3rd
# 8   14382  27689       Juventus  Mid 3rd
# 9   10923  23467          Lazio  Mid 3rd
# 10   9452  21337          Lecce  Mid 3rd
# 11  12420  25056          Milan  Mid 3rd
# 12  14301  28332         Napoli  Mid 3rd
# 13   9062  20215          Parma  Mid 3rd
# 14  11606  23491           Roma  Mid 3rd
# 15   9410  20183      Sampdoria  Mid 3rd
# 16  13298  26144       Sassuolo  Mid 3rd
# 17   9811  21112           SPAL  Mid 3rd
# 18   9564  21006         Torino  Mid 3rd
# 19   9704  21038        Udinese  Mid 3rd

# %%
d = {'Val':df_touch['Att 3rd'].values,  'Total':df_touch['Touches'].values, 'Squad': df_touch['Squad'].values, 'Zone': 'Att 3rd'}
Att_3rd = pd.DataFrame(data=d)

Att_3rd
# Out:
#      Val  Total          Squad     Zone
# 0   8153  26357       Atalanta  Att 3rd
# 1   6303  22942        Bologna  Att 3rd
# 2   4745  19036        Brescia  Att 3rd
# 3   5141  21166       Cagliari  Att 3rd
# 4   5861  21656     Fiorentina  Att 3rd
# 5   5265  22396          Genoa  Att 3rd
# 6   5594  21760  Hellas Verona  Att 3rd
# 7   6605  24871          Inter  Att 3rd
# 8   8109  27689       Juventus  Att 3rd
# 9   6707  23467          Lazio  Att 3rd
# 10  5167  21337          Lecce  Att 3rd
# 11  6986  25056          Milan  Att 3rd
# 12  8295  28332         Napoli  Att 3rd
# 13  4847  20215          Parma  Att 3rd
# 14  6550  23491           Roma  Att 3rd
# 15  5492  20183      Sampdoria  Att 3rd
# 16  6689  26144       Sassuolo  Att 3rd
# 17  5115  21112           SPAL  Att 3rd
# 18  5246  21006         Torino  Att 3rd
# 19  5094  21038        Udinese  Att 3rd

# %%
d = {'Val':df_touch['Att Pen'].values,  'Total':df_touch['Touches'].values,  'Squad': df_touch['Squad'].values, 'Zone': 'Att Pen'}
Att_Pen = pd.DataFrame(data=d)

Att_Pen
# Out:
#      Val  Total          Squad     Zone
# 0   1268  26357       Atalanta  Att Pen
# 1    886  22942        Bologna  Att Pen
# 2    734  19036        Brescia  Att Pen
# 3    655  21166       Cagliari  Att Pen
# 4    979  21656     Fiorentina  Att Pen
# 5    761  22396          Genoa  Att Pen
# 6    840  21760  Hellas Verona  Att Pen
# 7   1133  24871          Inter  Att Pen
# 8    998  27689       Juventus  Att Pen
# 9   1058  23467          Lazio  Att Pen
# 10   824  21337          Lecce  Att Pen
# 11  1067  25056          Milan  Att Pen
# 12  1062  28332         Napoli  Att Pen
# 13   833  20215          Parma  Att Pen
# 14  1103  23491           Roma  Att Pen
# 15   776  20183      Sampdoria  Att Pen
# 16   948  26144       Sassuolo  Att Pen
# 17   706  21112           SPAL  Att Pen
# 18   833  21006         Torino  Att Pen
# 19   793  21038        Udinese  Att Pen

# %%
touch_zone = pd.concat([Def_Pen, Def_3rd, Mid_3rd, Att_3rd, Att_Pen])
touch_zone.describe
# Out:
# <bound method NDFrame.describe of      Val  Total       Squad     Zone
# 0   2038  26357    Atalanta  Def Pen
# 1   2524  22942     Bologna  Def Pen
# 2   2728  19036     Brescia  Def Pen
# 3   2763  21166    Cagliari  Def Pen
# 4   2399  21656  Fiorentina  Def Pen
# ..   ...    ...         ...      ...
# 15   776  20183   Sampdoria  Att Pen
# 16   948  26144    Sassuolo  Att Pen
# 17   706  21112        SPAL  Att Pen
# 18   833  21006      Torino  Att Pen
# 19   793  21038     Udinese  Att Pen
#
# [100 rows x 4 columns]>

# %%
plt.figure(figsize=(20,15))

y = df_touch['TotDist']
x = df_touch['PrgDist']
h= df_touch['Squad']

ax = sns.scatterplot(x=x, y=y )

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'
)
#Juve highlighted
#plt.scatter(df.xG.where(df['Team']=='Juventus').dropna().values[0], df.xGA.where(df['Team']=='Juventus').dropna().values[0], color='r')

#plt.axhline(y=y.median(), color='gray', linestyle='-')
#plt.axvline(x=x.median(), color='gray', linestyle='-')
#ax = sns.scatterplot(x="Avg_temp", y="F_rate", hue="Class", data=temp_fert_2013)

for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

#ax.set_title('Seria A top scorers (sorted by xG per 90 mins), xG and xA (2019/2020)', fontproperties=heading_font, color="black",          position=(0.3, 1.05));

#plt.text(x=0.45, y=0.3, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('In opponents penalty area', fontproperties=lable_font)
plt.xlabel('Total Touches', fontproperties=lable_font)
sns.despine(left=True)

# %%
plt.figure(figsize=(20,5))

y = touch_zone['Val']*100/touch_zone['Total']
h = touch_zone['Zone']
x= touch_zone['Squad']

ax = sns.barplot(x=x, y=y, hue=h, )

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'
)
#Juve highlighted
#plt.scatter(df.xG.where(df['Team']=='Juventus').dropna().values[0], df.xGA.where(df['Team']=='Juventus').dropna().values[0], color='r')

#plt.axhline(y=y.median(), color='gray', linestyle='-')
#plt.axvline(x=x.median(), color='gray', linestyle='-')
#ax = sns.scatterplot(x="Avg_temp", y="F_rate", hue="Class", data=temp_fert_2013)

#for x_pos, y_pos, label in zip(x, y, labels):
 #   ax.annotate(label,             # The label for this point
  #              xy=(x_pos, y_pos), # Position of the corresponding point
   #             xytext=(7, 0),     # Offset text by 7 points to the right
    #            textcoords='offset points', # tell it to use offset points
     #           ha='left',         # Horizontally aligned to the left
      #          va='center')       # Vertical alignment is centered

#ax.set_title('Seria A top scorers (sorted by xG per 90 mins), xG and xA (2019/2020)', fontproperties=heading_font, color="black",          position=(0.3, 1.05));

#plt.text(x=0.45, y=0.3, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('In opponents penalty area', fontproperties=lable_font)
plt.xlabel('Total Touches', fontproperties=lable_font)
sns.despine(left=True)

# %%
df = pd.DataFrame({'CTQ-tool':np.random.choice(['a','b','c','d'],50),
                  'opinion':np.random.choice(['acceptable','unacceptable'],50)})

fig, ax = plt.subplots(2,2)
ax = ax.flatten()
tab = pd.crosstab(df['CTQ-tool'],df['opinion'])
for i,cat in enumerate(tab.index):
    tab.loc[cat].plot.pie(ax=ax[i],startangle=90)
    ax[i].set_ylabel('')
    ax[i].set_title(cat, fontweight='bold')

# %%
df
# Out:
#    CTQ-tool       opinion
# 0         b  unacceptable
# 1         d  unacceptable
# 2         c  unacceptable
# 3         b    acceptable
# 4         b    acceptable
# 5         b    acceptable
# 6         c  unacceptable
# 7         a  unacceptable
# 8         a    acceptable
# 9         a    acceptable
# 10        c  unacceptable
# 11        c    acceptable
# 12        d  unacceptable
# 13        b  unacceptable
# 14        c    acceptable
# 15        b  unacceptable
# 16        d    acceptable
# 17        c    acceptable
# 18        b  unacceptable
# 19        c  unacceptable
# 20        a    acceptable
# 21        d    acceptable
# 22        c    acceptable
# 23        b    acceptable
# 24        c  unacceptable
# 25        c    acceptable
# 26        a    acceptable
# 27        c  unacceptable
# 28        c  unacceptable
# 29        d    acceptable
# 30        a  unacceptable
# 31        c    acceptable
# 32        c  unacceptable
# 33        b    acceptable
# ...

# %%
tab
# Out:
# opinion   acceptable  unacceptable
# CTQ-tool
# a                  6             4
# b                  5             5
# c                  8            10
# d                  5             7

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic);

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
