# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('Juve_Season_20_21.csv')
df
# Out:
#           Date           Time         Round  Day Venue Result   GF   GA  \
# 0   2020-09-20  20:45 (12:45)   Matchweek 1  Sun  Home      W  3.0  0.0
# 1   2020-09-27  20:45 (12:45)   Matchweek 2  Sun  Away      D  2.0  2.0
# 2   2020-10-17  20:45 (12:45)   Matchweek 4  Sat  Away      D  1.0  1.0
# 3   2020-10-25  20:45 (13:45)   Matchweek 5  Sun  Home      D  1.0  1.0
# 4   2020-11-01  15:00 (08:00)   Matchweek 6  Sun  Away      W  4.0  1.0
# 5   2020-11-08  12:30 (05:30)   Matchweek 7  Sun  Away      D  1.0  1.0
# 6   2020-11-21  20:45 (13:45)   Matchweek 8  Sat  Home      W  2.0  0.0
# 7   2020-11-28  18:00 (11:00)   Matchweek 9  Sat  Away      D  1.0  1.0
# 8   2020-12-05  18:00 (11:00)  Matchweek 10  Sat  Home      W  2.0  1.0
# 9   2020-12-13  18:00 (11:00)  Matchweek 11  Sun  Away      W  3.0  1.0
# 10  2020-12-16  18:30 (11:30)  Matchweek 12  Wed  Home      D  1.0  1.0
# 11  2020-12-19  20:45 (13:45)  Matchweek 13  Sat  Away      W  4.0  0.0
# 12  2020-12-22  20:45 (13:45)  Matchweek 14  Tue  Home      L  0.0  3.0
# 13  2021-01-03  20:45 (13:45)  Matchweek 15  Sun  Home      W  4.0  1.0
# 14  2021-01-06  20:45 (13:45)  Matchweek 16  Wed  Away      W  3.0  1.0
# 15  2021-01-10  20:45 (13:45)  Matchweek 17  Sun  Home      W  3.0  1.0
# 16  2021-01-17  20:45 (13:45)  Matchweek 18  Sun  Away      L  0.0  2.0
# 17  2021-01-24  12:30 (05:30)  Matchweek 19  Sun  Home      W  2.0  0.0
# 18  2021-01-30  18:00 (11:00)  Matchweek 20  Sat  Away      W  2.0  0.0
# 19  2021-02-06  18:00 (11:00)  Matchweek 21  Sat  Home      W  2.0  0.0
# 20  2021-02-13  18:00 (11:00)  Matchweek 22  Sat  Away      L  0.0  1.0
# 21  2021-02-22  20:45 (13:45)  Matchweek 23  Mon  Home      W  3.0  0.0
# 22  2021-02-27  20:45 (13:45)  Matchweek 24  Sat  Away      D  1.0  1.0
# 23  2021-03-02  20:45 (13:45)  Matchweek 25  Tue  Home      W  3.0  0.0
# 24  2021-03-06  20:45 (13:45)  Matchweek 26  Sat  Home      W  3.0  1.0
# 25  2021-03-14  18:00 (11:00)  Matchweek 27  Sun  Away      W  3.0  1.0
# 26  2021-03-21  15:00 (08:00)  Matchweek 28  Sun  Home      L  0.0  1.0
# 27  2021-04-03  18:00 (10:00)  Matchweek 29  Sat  Away      D  2.0  2.0
# 28  2021-04-07  18:45 (10:45)   Matchweek 3  Wed  Home      W  2.0  1.0
# 29  2021-04-11  15:00 (07:00)  Matchweek 30  Sun  Home      W  3.0  1.0
# 28         Napoli  1.4  1.5  47.0         NaN  Giorgio Chiellini     4-4-2
# 29          Genoa  2.3  1.1  57.0         NaN  Giorgio Chiellini     4-4-2
# 30       Atalanta  1.2  0.7  56.0         NaN  Giorgio Chiellini     4-4-2
# 31          Parma  2.1  1.1  64.0         NaN   Leonardo Bonucci     4-4-2
# 32     Fiorentina  1.1  1.3  66.0         NaN  Giorgio Chiellini     3-5-2
# 33        Udinese  1.8  0.4  57.0         NaN   Leonardo Bonucci     4-4-2
# 34          Milan  1.0  1.2  56.0         NaN  Giorgio Chiellini     4-4-2
# 35       Sassuolo  NaN  NaN   NaN         NaN                NaN       NaN
# 36          Inter  NaN  NaN   NaN         NaN                NaN       NaN
# 37        Bologna  NaN  NaN   NaN         NaN                NaN       NaN
#
#                 Referee  Match Report  Notes
# 0       Marco Piccinini  Match Report    NaN
# 1        Marco Di Bello  Match Report    NaN
# 2    Francesco Fourneau  Match Report    NaN
# 3       Fabrizio Pasqua  Match Report    NaN
# 4        Rosario Abisso  Match Report    NaN
# 5          Davide Massa  Match Report    NaN
# 6         Fabio Maresca  Match Report    NaN
# 7       Fabrizio Pasqua  Match Report    NaN
# 8        Daniele Orsato  Match Report    NaN
# 9        Marco Di Bello  Match Report    NaN
# 10       Daniele Doveri  Match Report    NaN
# 11  Giampaolo Calvarese  Match Report    NaN
# 12    Federico La Penna  Match Report    NaN
# 13     Piero Giacomelli  Match Report    NaN
# 14  Massimiliano Irrati  Match Report    NaN
# 15         Davide Massa  Match Report    NaN
# 16       Daniele Doveri  Match Report    NaN
# 17          Juan Sacchi  Match Report    NaN
# 18       Michael Fabbri  Match Report    NaN
# 19       Daniele Orsato  Match Report    NaN
# 20       Daniele Doveri  Match Report    NaN
# 21       Valerio Marini  Match Report    NaN
# 22        Fabio Maresca  Match Report    NaN
# 23          Juan Sacchi  Match Report    NaN
# 24         Davide Massa  Match Report    NaN
# 25  Giampaolo Calvarese  Match Report    NaN
# 26       Rosario Abisso  Match Report    NaN
# 27       Michael Fabbri  Match Report    NaN
# 28     Maurizio Mariani  Match Report    NaN
# 29       Marco Di Bello  Match Report    NaN
# 30       Daniele Orsato  Match Report    NaN
# 31     Piero Giacomelli  Match Report    NaN
# 32         Davide Massa  Match Report    NaN
# 33       Daniele Chiffi  Match Report    NaN
# 34         Paolo Valeri  Match Report    NaN
# 35                  NaN  Head-to-Head    NaN
# 36                  NaN  Head-to-Head    NaN
# 37                  NaN  Head-to-Head    NaN

# %%
df.columns.values
# Out:
# array(['Date', 'Time', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain',
#        'Formation', 'Referee', 'Match Report', 'Notes'], dtype=object)

# %%
df_clean = df[['Date', 'Round', 'Result', 'GF', 'GA',
       'Opponent', 'xG', 'xGA']]
df_clean.head()
# Out:
#          Date        Round Result   GF   GA       Opponent   xG  xGA
# 0  2020-09-20  Matchweek 1      W  3.0  0.0      Sampdoria  2.4  0.8
# 1  2020-09-27  Matchweek 2      D  2.0  2.0           Roma  1.3  2.7
# 2  2020-10-17  Matchweek 4      D  1.0  1.0        Crotone  1.6  1.1
# 3  2020-10-25  Matchweek 5      D  1.0  1.0  Hellas Verona  1.8  0.7
# 4  2020-11-01  Matchweek 6      W  4.0  1.0         Spezia  3.4  0.7

# %%
df_clean[['xG', 'xGA']].plot.line()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

import matplotlib.font_manager as fm
# Font Imports
heading_font = fm.FontProperties(fname='PlayfairDisplay-Regular.ttf', size=28)

subtitle_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=18)

lable_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=20)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

plt.figure(figsize=(15,10))

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

x = df['xG']
y = df['xGA']
labels = df['Opponent']

ax = sns.scatterplot(x=x, y=y, linewidths=2)

for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

# %%
df_melt = df.reset_index().melt('Round', var_name='cols',  value_name='vals')
df_melt
# Out:
#             Round   cols vals
# 0     Matchweek 1  index    0
# 1     Matchweek 2  index    1
# 2     Matchweek 4  index    2
# 3     Matchweek 5  index    3
# 4     Matchweek 6  index    4
# ..            ...    ...  ...
# 679  Matchweek 34  Notes  NaN
# 680  Matchweek 35  Notes  NaN
# 681  Matchweek 36  Notes  NaN
# 682  Matchweek 37  Notes  NaN
# 683  Matchweek 38  Notes  NaN
#
# [684 rows x 3 columns]

# %%
df = pd.DataFrame()
df['Team'] = dframe['Unnamed: 1_level_0', 'Squad']
df['xG'] = dframe['Home', 'xG']
df['xGA'] = dframe['Home', 'xGA']
df
# Out:
#              Team    xG   xGA
# 0        Juventus  28.5   9.3
# 1           Lazio  31.4  17.2
# 2           Inter  21.4  12.8
# 3        Atalanta  29.1  11.2
# 4            Roma  28.1  16.4
# 5          Napoli  25.4  14.4
# 6           Milan  18.5  16.4
# 7   Hellas Verona  17.0  13.6
# 8           Parma  18.7  16.5
# 9         Bologna  17.6  18.3
# 10       Sassuolo  21.2  18.5
# 11       Cagliari  16.8  19.4
# 12     Fiorentina  17.8  15.2
# 13        Udinese  14.0  16.5
# 14         Torino  11.1  22.9
# 15      Sampdoria  21.8  17.3
# 16          Genoa  16.7  18.0
# 17          Lecce  16.4  27.5
# 18           SPAL  16.5  18.9
# 19        Brescia  15.5  25.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

import matplotlib.font_manager as fm
# Font Imports
heading_font = fm.FontProperties(fname='PlayfairDisplay-Regular.ttf', size=28)

subtitle_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=18)

lable_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=20)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

plt.figure(figsize=(15,10))

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

x = df['xG']
y = df['xGA']
labels = df['Team']

ax = sns.scatterplot(x=x, y=y, linewidths=2)

#Juve highlighted
plt.scatter(df.xG.where(df['Team']=='Juventus').dropna().values[0], df.xGA.where(df['Team']=='Juventus').dropna().values[0], color='r')

plt.axhline(y=y.median(), color='gray', linestyle='-')
plt.axvline(x=x.median(), color='gray', linestyle='-')
#ax = sns.scatterplot(x="Avg_temp", y="F_rate", hue="Class", data=temp_fert_2013)

for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

ax.set_title('Seria A clubs, HOME xG and xGA (2019/2020)', fontproperties=heading_font, color="black",
         position=(0.3, 1.05));

plt.text(x=33, y=6, s='Data souce: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Expected Goals(xG)', fontproperties=lable_font)
plt.ylabel('Expected Goals Allowed(xGA)', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_away = pd.DataFrame()
df_away['Team'] = dframe['Unnamed: 1_level_0', 'Squad']
df_away['xG'] = dframe['Away', 'xG']
df_away['xGA'] = dframe['Away', 'xGA']

# %%
df.xG.where(df['Team']=='Juventus').dropna().values[0]
# Out:
# 28.5

# %%
plt.scatter(df.xG.where(df['Team']=='Juventus').dropna().values[0], df.xGA.where(df['Team']=='Juventus').dropna().values[0], color='r')

# %%
x = df_away['xG']
y = df_away['xGA']
labels = df_away['Team']

plt.figure(figsize=(15,10))
ax = sns.scatterplot(x=x, y=y, linewidths=2)

# Juve highlighted
plt.scatter(df_away.xG.where(df_away['Team']=='Juventus').dropna().values[0], df_away.xGA.where(df_away['Team']=='Juventus').dropna().values[0], color='r')

plt.axhline(y=y.median(), color='gray', linestyle='-')
plt.axvline(x=x.median(), color='gray', linestyle='-')
#ax = sns.scatterplot(x="Avg_temp", y="F_rate", hue="Class", data=temp_fert_2013)

for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

ax.set_title('Seria A clubs, AWAY xG and xGA (2019/2020)', fontproperties=heading_font, color="black",
         position=(0.3, 1.05));

plt.text(x=35, y=10, s='Data souce: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Expected Goals(xG)', fontproperties=lable_font)
plt.ylabel('Expected Goals Allowed(xGA)', fontproperties=lable_font)
sns.despine(left=True)
