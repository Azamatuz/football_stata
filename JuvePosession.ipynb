# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('juvePoss2021.csv', header=1)
df
# Out:
#                                          Player   Nation   Pos   Age   90s  \
# 0                                 Danilo\Danilo   br BRA    DF  29.0  32.4
# 1           Cristiano Ronaldo\Cristiano-Ronaldo   pt POR    FW  35.0  31.1
# 2           Wojciech Szczęsny\Wojciech-Szczesny   pl POL    GK  30.0  29.7
# 3               Federico Chiesa\Federico-Chiesa   it ITA  MFDF  22.0  24.6
# 4           Rodrigo Bentancur\Rodrigo-Bentancur   uy URU    MF  23.0  25.8
# 5                   Juan Cuadrado\Juan-Cuadrado   co COL  DFMF  32.0  24.2
# 6                   Adrien Rabiot\Adrien-Rabiot   fr FRA    MF  25.0  25.7
# 7             Matthijs de Ligt\Matthijs-de-Ligt   nl NED    DF  20.0  24.7
# 8             Leonardo Bonucci\Leonardo-Bonucci   it ITA    DF  33.0  22.5
# 9                   Álvaro Morata\Alvaro-Morata   es ESP    FW  27.0  22.4
# 10                      Alex Sandro\Alex-Sandro   br BRA    DF  29.0  20.6
# ...

# %%
# remove first name of players

for key, name in enumerate(df.Player):
    splitting = name.split('-')
    if len(splitting)>1:
        
        df.Player[key] = splitting[1]
    else:
        df.Player[key] = splitting[0]
# Out:
# <ipython-input-3-5250b1ce5933>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Player[key] = splitting[0]
# <ipython-input-3-5250b1ce5933>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Player[key] = splitting[1]

# %%
# droppping unnecessary rows
df = df.drop(df.tail(2).index)
# could be used (inplace = True)

# %%
#drop unnecessary columns

# %%
df.Player
# Out:
# 0     Danilo\Danilo
# 1           Ronaldo
# 2          Szczesny
# 3            Chiesa
# 4         Bentancur
# 5          Cuadrado
# 6            Rabiot
# 7                de
# 8           Bonucci
# 9            Morata
# 10           Sandro
# 11       Kulusevski
# 12         McKennie
# 13        Chiellini
# 14           Dybala
# 15             Melo
# 16           Ramsey
# 17          Demiral
# 18     Bernardeschi
# 19           Buffon
# 20         Frabotta
# 21        Portanova
# 22            Costa
# 23               De
# 24        Pinsoglio
# 25          Fagioli
# 26               Di
# 27          Correia
# 28         Dragusin
# 29           Vrioni
# Name: Player, dtype: object

# %%
df.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', '90s', 'Touches', 'Def Pen',
#        'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att Pen', 'Live', 'Succ', 'Att',
#        'Succ%', '#Pl', 'Megs', 'Carries', 'TotDist', 'PrgDist', 'Prog', '1/3',
#        'CPA', 'Mis', 'Dis', 'Targ', 'Rec', 'Rec%', 'Prog.1', 'Matches'],
#       dtype='object')

# %%
df_short = df[['Player','Pos', 'Age', '90s', 'Touches', 'Def Pen',
       'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att Pen',]]

# %%
df_short.head()
# Out:
#           Player   Pos   Age   90s  Touches  Def Pen  Def 3rd  Mid 3rd  \
# 0  Danilo\Danilo    DF  29.0  32.4     2747      162      909     1577
# 1        Ronaldo    FW  35.0  31.1     1462       19       75      675
# 2       Szczesny    GK  30.0  29.7     1076      935     1066       10
# 3         Chiesa  MFDF  22.0  24.6     1100       22      165      457
# 4      Bentancur    MF  23.0  25.8     2122      115      564     1303
#
#    Att 3rd  Att Pen
# 0      416       24
# 1      846      213
# 2        0        0
# 3      579      122
# 4      385       15

# %%
df_short.to_csv(index=False)
# Out:
# 'Player,Pos,Age,90s,Touches,Def Pen,Def 3rd,Mid 3rd,Att 3rd,Att Pen\r\nDanilo\\Danilo,DF,29.0,32.4,2747,162,909,1577,416,24\r\nRonaldo,FW,35.0,31.1,1462,19,75,675,846,213\r\nSzczesny,GK,30.0,29.7,1076,935,1066,10,0,0\r\nChiesa,MFDF,22.0,24.6,1100,22,165,457,579,122\r\nBentancur,MF,23.0,25.8,2122,115,564,1303,385,15\r\nCuadrado,DFMF,32.0,24.2,2048,45,471,963,750,72\r\nRabiot,MF,25.0,25.7,1760,97,481,1022,415,46\r\nde,DF,20.0,24.7,1923,264,860,1069,103,30\r\nBonucci,DF,33.0,22.5,1670,238,831,897,59,20\r\nMorata,FW,27.0,22.4,894,24,73,426,455,148\r\nSandro,DF,29.0,20.6,1638,121,508,879,370,41\r\nKulusevski,MFFW,20.0,21.4,1047,7,126,450,564,143\r\nMcKennie,MF,21.0,18.9,1000,37,183,517,354,81\r\nChiellini,DF,35.0,15.4,1228,186,584,663,51,13\r\nDybala,FW,26.0,12.6,892,3,67,401,477,67\r\nMelo,MF,23.0,12.9,1168,50,324,719,224,10\r\nRamsey,MF,29.0,12.1,862,17,122,446,352,71\r\nDemiral,DF,22.0,10.4,729,111,396,335,29,12\r\nBernardeschi,DFMF,26.0,10.8,714,32,151,320,303,36\r\nBuffon,GK,42.0,8.0
# ...

# %%
df_short.to_excel("juvePoss_short.xlsx")

# %%
# Plot the DefPen touches
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))
sns.set_color_codes("pastel")
sns.barplot(x="Def Pen", y="Player", data=df_short,
            label="Def Pen", color="b")
sns.set_color_codes("pastel")
sns.barplot(x="Def 3rd", y="Player", data=df_short,
            label="Def 3rd", color="g")

sns.despine(left=True, bottom=True)

# %%
f, ax = plt.subplots(figsize=(6, 15))
df_short[['Def Pen','Def 3rd','Mid 3rd','Att 3rd','Att Pen']].plot(kind="bar")
# Out:
# <AxesSubplot:>
