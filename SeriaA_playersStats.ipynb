# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('PlayerStandardStats.csv', header=1)
df.head()
# Out:
#    Rk                               Player  Nation Pos     Squad  Age  Born  \
# 0   1      Arkadiusz Milik\Arkadiusz-Milik  pl POL  FW    Napoli   25  1994
# 1   2                Edin Džeko\Edin-Dzeko  ba BIH  FW      Roma   33  1986
# 2   3            Josip Iličić\Josip-Ilicic  si SVN  FW  Atalanta   31  1988
# 3   4    Lautaro Martínez\Lautaro-Martinez  ar ARG  FW     Inter   21  1997
# 4   5  Cristiano Ronaldo\Cristiano-Ronaldo  pt POR  FW  Juventus   34  1985
#
#    MP  Starts   Min  Gls  Ast  PK  PKatt  CrdY  CrdR  Gls.1  Ast.1   G+A  \
# 0  16      14  1232    9    0   0      0     4     0   0.66   0.00  0.66
# 1  25      23  2123   12    4   0      0     4     0   0.51   0.17  0.68
# 2  21      19  1482   15    5   0      0     1     1   0.91   0.30  1.21
# 3  22      20  1663   11    1   2      2     6     1   0.60   0.05  0.65
# 4  22      22  1944   21    3   7      7     2     0   0.97   0.14  1.11
#
# ...

# %%
df.describe()
# Out:
#                Rk         Age         Born          MP      Starts  \
# count  206.000000  206.000000   206.000000  206.000000  206.000000
# mean   103.500000   26.621359  1992.067961   21.388350   19.684466
# std     59.611241    4.112127     4.094642    2.759403    3.511994
# min      1.000000   19.000000  1981.000000   15.000000   12.000000
# 25%     52.250000   24.000000  1989.000000   20.000000   17.000000
# 50%    103.500000   26.000000  1992.000000   22.000000   20.000000
# 75%    154.750000   30.000000  1995.000000   23.000000   22.000000
# max    206.000000   37.000000  2000.000000   26.000000   26.000000
#
#                Min         Gls         Ast          PK       PKatt  \
# count   206.000000  206.000000  206.000000  206.000000  206.000000
# mean   1730.475728    2.427184    1.703883    0.388350    0.456311
# std     314.132576    3.805264    1.974146    1.304648    1.476824
# min    1170.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
for key, name in enumerate(df.Player):
    splitting = name.split('\\')
    df.Player[key] = splitting[1]
# Out:
# /home/azamatuz/anaconda3/envs/myenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head(20)
# Out:
#     Rk             Player  Nation   Pos     Squad  Age  Born  MP  Starts  \
# 0    1    Arkadiusz-Milik  pl POL    FW    Napoli   25  1994  16      14
# 1    2         Edin-Dzeko  ba BIH    FW      Roma   33  1986  25      23
# 2    3       Josip-Ilicic  si SVN    FW  Atalanta   31  1988  21      19
# 3    4   Lautaro-Martinez  ar ARG    FW     Inter   21  1997  22      20
# 4    5  Cristiano-Ronaldo  pt POR    FW  Juventus   34  1985  22      22
# 5    6     Joaquin-Correa  ar ARG  FWMF     Lazio   24  1994  22      17
# 6    7    Mario-Balotelli  it ITA    FW   Brescia   28  1990  19      16
# 7    8      Romelu-Lukaku  be BEL    FW     Inter   26  1993  25      24
# 8    9    Gonzalo-Higuain  ar ARG    FW  Juventus   31  1987  23      16
# 9   10   Francesco-Caputo  it ITA    FW  Sassuolo   31  1987  23      22
# 10  11      Ciro-Immobile  it ITA    FW     Lazio   29  1990  26      25
# 11  12      Mario-Pasalic  hr CRO    MF  Atalanta   24  1995  23      20
# ...

# %%
df = df.sort_values(by=['Gls.1'], ascending=False)
df.head(20)
# Out:
#       Rk              Player  Nation   Pos      Squad  Age  Born  MP  Starts  \
# 10    11       Ciro-Immobile  it ITA    FW      Lazio   29  1990  26      25
# 4      5   Cristiano-Ronaldo  pt POR    FW   Juventus   34  1985  22      22
# 2      3        Josip-Ilicic  si SVN    FW   Atalanta   31  1988  21      19
# 7      8       Romelu-Lukaku  be BEL    FW      Inter   26  1993  25      24
# 0      1     Arkadiusz-Milik  pl POL    FW     Napoli   25  1994  16      14
# 29    30          Joao-Pedro  br BRA  FWMF   Cagliari   27  1992  25      25
# 9     10    Francesco-Caputo  it ITA    FW   Sassuolo   31  1987  23      22
# 3      4    Lautaro-Martinez  ar ARG    FW      Inter   21  1997  22      20
# 1      2          Edin-Dzeko  ba BIH    FW       Roma   33  1986  25      23
# 27    28    Domenico-Berardi  it ITA    FW   Sassuolo   24  1994  20      19
# 35    36       Marco-Mancosu  it ITA  MFFW      Lecce   30  1988  21      17
# ...

# %%
df = df.sort_values(by=['Ast.1'], ascending=False)
df.head(20)
# Out:
#       Rk              Player  Nation   Pos     Squad  Age  Born  MP  Starts  \
# 40    41        Luis-Alberto  es ESP    MF     Lazio   26  1992  25      25
# 43    44  Lorenzo-Pellegrini  it ITA    MF      Roma   23  1996  18      18
# 15    16          Papu-Gomez  ar ARG  MFFW  Atalanta   31  1988  24      23
# 179  180   Rodrigo-Bentancur  uy URU    MF  Juventus   22  1997  19      15
# 115  116    Antonio-Candreva  it ITA  DFMF     Inter   32  1987  20      16
# 48    49   Dejan-Kulusekvski  se SWE  FWMF     Parma   19  2000  23      22
# 50    51       Jose-Callejon  es ESP  MFFW    Napoli   32  1987  23      19
# 60    61    Radja-Nainggolan  be BEL  MFFW  Cagliari   31  1988  21      20
# 2      3        Josip-Ilicic  si SVN    FW  Atalanta   31  1988  21      19
# 28    29       Dries-Mertens  be BEL    FW    Napoli   32  1987  21      12
# 10    11       Ciro-Immobile  it ITA    FW     Lazio   29  1990  26      25
# ...

# %%
df_20 = df.head(20)[['Player', 'Gls.1', 'xG.1']]
df_20['diff'] = df_20['Gls.1'] - df_20['xG.1']
df_20 = df_20.sort_values(by=['diff'], ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df_20['Player'], y=df_20['diff'], palette="vlag")
ax.axhline(0, color="k", clip_on=False)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light'
)
plt.text(x=-1, y=0.43,s='Top snipers of Seria A (2019/2020)',fontproperties=heading_font, color="black")
plt.text(x=-1, y=0.4, s='Based on statistic per 90 minutes',fontproperties=subtitle_font,color='#524939')

plt.text(x=20, y=-0.3, s='Data souce: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')


plt.xlabel(' ', fontproperties=lable_font)
plt.ylabel('Diff. b/w Actual Goals and Expected Goals (Gls-xG)', fontproperties=lable_font)
# Out:
# Text(0, 0.5, 'Diff. b/w Actual Goals and Expected Goals (Gls-xG)')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

import matplotlib.font_manager as fm
# Font Imports
heading_font = fm.FontProperties(fname='PlayfairDisplay-Regular.ttf', size=28)

subtitle_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=18)

lable_font = fm.FontProperties(fname='Roboto-Regular.ttf', size=20)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

plt.figure(figsize=(15,10))

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

x = df_20['Gls.1']
y = df_20['xG.1']
labels = df_20['Player']

ax = sns.scatterplot(x=x, y=y, linewidths=2)

#Juve highlighted
#plt.scatter(df.xG.where(df['Team']=='Juventus').dropna().values[0], df.xGA.where(df['Team']=='Juventus').dropna().values[0], color='r')

#plt.axhline(y=y.median(), color='gray', linestyle='-')
#plt.axvline(x=x.median(), color='gray', linestyle='-')
#ax = sns.scatterplot(x="Avg_temp", y="F_rate", hue="Class", data=temp_fert_2013)

for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

#ax.set_title('Seria A clubs, HOME xG and xGA (2019/2020)', fontproperties=heading_font, color="black",          position=(0.3, 1.05));

#plt.text(x=33, y=6, s='Data souce: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Expected Goals(xG)', fontproperties=lable_font)
plt.ylabel('Expected Goals Allowed(xGA)', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_20_goal = df.head(20)[['Player', 'Gls.1', 'Ast.1']]

# %%
# https://teamcolorcodes.com/soccer/serie-a-color-codes/ team colors

# %%
plt.figure(figsize=(15,15))

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

y = df_20_goal['Gls.1']
x = df_20_goal['Ast.1']
labels = df_20_goal['Player']

ax = sns.scatterplot(x=x, y=y, linewidths=2)

#Juve highlighted
plt.scatter(df['Ast.1'].where(df['Player']=='Paulo-Dybala').dropna().values[0], df['Gls.1'].where(df['Player']=='Paulo-Dybala').dropna().values[0], color='black')
plt.scatter(df['Ast.1'].where(df['Player']=='Cristiano-Ronaldo').dropna().values[0], df['Gls.1'].where(df['Player']=='Cristiano-Ronaldo').dropna().values[0], color='black')



for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(10, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

ax.set_title('Generosity of top 20 goal scorers in Seria A (2019/2020)', fontproperties=heading_font, color="black",          position=(0.4, 1.05));

plt.text(x=0.33, y=0.2, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('Goals per 90 mins (Gls.1)', fontproperties=lable_font)
plt.xlabel('Assists per 90 mins (Ast.1)', fontproperties=lable_font)
sns.despine(left=True)

# %%
df = df.sort_values(by=['Ast'], ascending=False)
df_20_ast = df.head(20)[['Player', 'Ast', 'Gls.1', 'Ast.1']]
df_20_ast
# Out:
#                  Player  Ast  Gls.1  Ast.1
# 40         Luis-Alberto   12   0.17   0.50
# 15           Papu-Gomez   10   0.29   0.48
# 43   Lorenzo-Pellegrini    8   0.06   0.48
# 48    Dejan-Kulusekvski    7   0.24   0.33
# 10        Ciro-Immobile    7   1.11   0.29
# 179   Rodrigo-Bentancur    6   0.00   0.41
# 50        Jose-Callejon    6   0.11   0.33
# 60     Radja-Nainggolan    6   0.26   0.31
# 32         Robin-Gosens    5   0.36   0.26
# 11        Mario-Pasalic    5   0.27   0.27
# 137       Sandro-Tonali    5   0.04   0.22
# 19      Lorenzo-Insigne    5   0.24   0.24
# 73         Rafael-Toloi    5   0.05   0.25
# 114     Paolo-Ghiglione    5   0.00   0.28
# 2          Josip-Ilicic    5   0.91   0.30
# 115    Antonio-Candreva    5   0.13   0.34
# 59     Marcelo-Brozovic    5   0.14   0.23
# 27     Domenico-Berardi    5   0.50   0.28
# 1            Edin-Dzeko    4   0.51   0.17
# 153     Luca-Pellegrini    4   0.00   0.22

# %%
plt.figure(figsize=(15,15))

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

x = df_20_ast['Gls.1']
y = df_20_ast['Ast.1']
labels = df_20_ast['Player']

ax = sns.scatterplot(x=x, y=y, linewidths=2)

#Juve highlighted
#plt.scatter(df['Ast.1'].where(df['Player']=='Paulo-Dybala').dropna().values[0], df['Gls.1'].where(df['Player']=='Paulo-Dybala').dropna().values[0], color='black')
#plt.scatter(df['Ast.1'].where(df['Player']=='Cristiano-Ronaldo').dropna().values[0], df['Gls.1'].where(df['Player']=='Cristiano-Ronaldo').dropna().values[0], color='black')



for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(10, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

ax.set_title('Generosity of top 20 goal scorers in Seria A (2019/2020)', fontproperties=heading_font, color="black",          position=(0.4, 1.05));

plt.text(x=0.33, y=0.2, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Goals per 90 mins (Gls.1)', fontproperties=lable_font)
plt.ylabel('Assists per 90 mins (Ast.1)', fontproperties=lable_font)
sns.despine(left=True)
