# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
# Libraries
from math import pi

# %%
df = pd.read_csv('Juv_laz.csv', header=1)
df
# Out:
#                                          Player     #  Nation  Pos     Age  \
# 0           Rodrigo Bentancur\Rodrigo-Bentancur  30.0  uy URU   CM  23-156
# 1             Leonardo Bonucci\Leonardo-Bonucci  19.0  it ITA   CB  33-191
# 2                   Juan Cuadrado\Juan-Cuadrado  16.0  co COL   WB  32-166
# 3             Dejan Kulusevski\Dejan-Kulusevski  44.0  se SWE   RW  20-197
# 4                   Adrien Rabiot\Adrien-Rabiot  25.0  fr FRA   CM  25-219
# 5                   Álvaro Morata\Alvaro-Morata   9.0  es ESP   FW  28-016
# 6           Cristiano Ronaldo\Cristiano-Ronaldo   7.0  pt POR   LW  35-277
# 7           Gianluca Frabotta\Gianluca-Frabotta  38.0  it ITA   WB  21-137
# 8                                 Danilo\Danilo  13.0  br BRA   CB  29-116
# 9                     Paulo Dybala\Paulo-Dybala  10.0  ar ARG   LW  26-359
# 10                  Merih Demiral\Merih-Demiral  28.0  tr TUR   CB  22-248
# ...

# %%
df = df.drop(14)

# %%
for key, name in enumerate(df.Player):
    if '-' in name:
        splitting = name.split('-')
        df.Player[key] = splitting[1]
    else: 
        df.Player[key] = name
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Age']
# Out:
# 0     23-156
# 1     33-191
# 2     32-166
# 3     20-197
# 4     25-219
# 5     28-016
# 6     35-277
# 7     21-137
# 8     29-116
# 9     26-359
# 10    22-248
# 11    30-204
# 12    22-072
# 13    26-266
# Name: Age, dtype: object

# %%
for key, age in enumerate(df.Age):
    splitting = age.split('-')
    df.Age[key] = splitting[0]
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.Age = df.Age.astype(int)

# %%
df_age = df[['Player', 'Age']]

# %%
df_age.dtypes
# Out:
# Player    object
# Age       object
# dtype: object

# %%
df_age.describe()
# Out:
#              Age
# count  14.000000
# mean   26.571429
# std     4.750940
# min    20.000000
# 25%    22.250000
# 50%    26.000000
# 75%    29.750000
# max    35.000000

# %%
ax = sns.boxplot( y=df["Age"] )
ax = sns.swarmplot( y="Age", data=df_age, color="red", size=10)

# %%
df_sum = df[['Player', 'Sh','Touches', 'Press', 'Tkl', 'Int', 'Blocks▼']]
df_sum
# Out:
#            Player  Sh  Touches  Press  Tkl  Int  Blocks▼
# 0       Bentancur   1       80     25    1    1        6
# 1         Bonucci   0       68      5    0    0        5
# 2        Cuadrado   0       70     15    5    1        4
# 3      Kulusevski   2       43     21    1    0        3
# 4          Rabiot   3       61     21    4    1        3
# 5          Morata   0       38     12    1    0        1
# 6         Ronaldo   5       40      5    0    1        1
# 7        Frabotta   0       34     18    1    0        1
# 8   Danilo\Danilo   0       89      3    1    2        1
# 9          Dybala   0       15      1    0    0        1
# 10        Demiral   0       67      8    2    1        0
# 11       Szczesny   0       32      0    0    0        0
# 12       McKennie   0        7      8    2    0        0
# 13   Bernardeschi   0        2      0    0    0        0

# %%
df_sum.columns = ['Player', 'Shots', 'Touches', 'Press', 'Tackled', 'Interceptions', 'Blocks']
df_sum = df_sum.set_index('Player')

# %%
df_trans = df_sum.T # or df1.transpose()

df_trans
# Out:
# Player         Bentancur  Bonucci  Cuadrado  Kulusevski  Rabiot  Morata  \
# Shots                  1        0         0           2       3       0
# Touches               80       68        70          43      61      38
# Press                 25        5        15          21      21      12
# Tackled                1        0         5           1       4       1
# Interceptions          1        0         1           0       1       0
# Blocks                 6        5         4           3       3       1
#
# Player         Ronaldo  Frabotta  Danilo\Danilo  Dybala  Demiral  Szczesny  \
# Shots                5         0              0       0        0         0
# Touches             40        34             89      15       67        32
# Press                5        18              3       1        8         0
# Tackled              0         1              1       0        2         0
# Interceptions        1         0              2       0        1         0
# ...

# %%
df_sum.Shots.max()
# Out:
# 25

# %%
df_sum.Shots/5
# Out:
# Player
# Bentancur        0.2
# Bonucci          0.0
# Cuadrado         0.0
# Kulusevski       0.4
# Rabiot           0.6
# Morata           0.0
# Ronaldo          1.0
# Frabotta         0.0
# Danilo\Danilo    0.0
# Dybala           0.0
# Demiral          0.0
# Szczesny         0.0
# McKennie         0.0
# Bernardeschi     0.0
# Name: Shots, dtype: float64

# %%
df_sum_copy = df_sum.copy()
df_sum_copy = df_sum_copy.astype(float).round(2)
df_sum_copy
# Out:
#                Shots  Touches  Press  Tackled  Interceptions  Blocks
# Player
# Bentancur        1.0     80.0   25.0      1.0            1.0     6.0
# Bonucci          0.0     68.0    5.0      0.0            0.0     5.0
# Cuadrado         0.0     70.0   15.0      5.0            1.0     4.0
# Kulusevski       2.0     43.0   21.0      1.0            0.0     3.0
# Rabiot           3.0     61.0   21.0      4.0            1.0     3.0
# Morata           0.0     38.0   12.0      1.0            0.0     1.0
# Ronaldo          5.0     40.0    5.0      0.0            1.0     1.0
# Frabotta         0.0     34.0   18.0      1.0            0.0     1.0
# Danilo\Danilo    0.0     89.0    3.0      1.0            2.0     1.0
# Dybala           0.0     15.0    1.0      0.0            0.0     1.0
# Demiral          0.0     67.0    8.0      2.0            1.0     0.0
# Szczesny         0.0     32.0    0.0      0.0            0.0     0.0
# ...

# %%
df_columns = df_sum_copy.columns
df_columns
# Out:
# Index(['Shots', 'Touches', 'Press', 'Tackled', 'Interceptions', 'Blocks'], dtype='object')

# %%
df_sum_copy
# Out:
#   File "<ipython-input-186-d5120498c5a1>", line 1
#     df_sum_copy.1
#                 ^
# SyntaxError: invalid syntax

# %%
#f"Shepherd {shepherd} is {age} years old."
for key, val in enumerate(df_sum_copy):
    df_sum_copy[f'{val}'] = df_sum_copy[f'{val}']/df_sum_copy[f'{val}'].max()

df_sum_copy = df_sum_copy.round(2)
df_sum_copy
# Out:
#                Shots  Touches  Press  Tackled  Interceptions  Blocks
# Player
# Bentancur        0.2     0.90   1.00      0.2            0.5    1.00
# Bonucci          0.0     0.76   0.20      0.0            0.0    0.83
# Cuadrado         0.0     0.79   0.60      1.0            0.5    0.67
# Kulusevski       0.4     0.48   0.84      0.2            0.0    0.50
# Rabiot           0.6     0.69   0.84      0.8            0.5    0.50
# Morata           0.0     0.43   0.48      0.2            0.0    0.17
# Ronaldo          1.0     0.45   0.20      0.0            0.5    0.17
# Frabotta         0.0     0.38   0.72      0.2            0.0    0.17
# Danilo\Danilo    0.0     1.00   0.12      0.2            1.0    0.17
# Dybala           0.0     0.17   0.04      0.0            0.0    0.17
# Demiral          0.0     0.75   0.32      0.4            0.5    0.00
# Szczesny         0.0     0.36   0.00      0.0            0.0    0.00
# ...

# %%
# Set data
df_test = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

# %%
df_test
# Out:
#   group  var1  var2  var3  var4  var5
# 0     A  38.0    29     8     7    28
# 1     B   1.5    10    39    31    15
# 2     C  30.0     9    23    33    32
# 3     D   4.0    34    24    14    14

# %%
list(df_test)
# Out:
# ['group', 'var1', 'var2', 'var3', 'var4', 'var5']

# %%
list(df_sum_copy)
# Out:
# ['Shots', 'Touches', 'Press', 'Tackled', 'Interceptions', 'Blocks']

# %%
df_sum_copy.index[1]
# Out:
# 'Bonucci'

# %%
 
# number of variable
categories=list(df_sum_copy)
N = len(categories)
categories
# Out:
# ['Shots', 'Touches', 'Press', 'Tackled', 'Interceptions', 'Blocks']

# %%
list(df_sum_copy.index)
# Out:
# ['Bentancur',
#  'Bonucci',
#  'Cuadrado',
#  'Kulusevski',
#  'Rabiot',
#  'Morata',
#  'Ronaldo',
#  'Frabotta',
#  'Danilo\\Danilo',
#  'Dybala',
#  'Demiral',
#  'Szczesny',
#  'McKennie',
#  'Bernardeschi']

# %%
for i in range(len(df_sum_copy.index)):    
# But we need to repeat the first value to close the circular graph:
    values=df_sum_copy.iloc[i].values.flatten().tolist()
    values += values[:1]
     
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    plt.figure()
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
    plt.ylim(0,1)

    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')
    plt.title(str(df_sum_copy.index[i]))

    # Fill area
    ax.fill(angles, values, 'b', alpha=0.1)
    plt.savefig((str(df_sum_copy.index[i]) + ".png"))
plt.show()

# %%
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
plt.ylim(0,1)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
plt.title("f{}")
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)
