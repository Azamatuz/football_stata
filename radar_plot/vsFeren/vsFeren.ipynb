# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
# Libraries
from math import pi

# %%
df = pd.read_csv('vsFeren.csv', header=1)
df
# Out:
#                                          Player     #   Nation  Pos     Age  \
# 0           Cristiano Ronaldo\Cristiano-Ronaldo   7.0   pt POR   FW  35-293
# 1                     Paulo Dybala\Paulo-Dybala  10.0   ar ARG   FW  27-009
# 2                   Álvaro Morata\Alvaro-Morata   9.0   es ESP   FW  28-032
# 3   Federico Bernardeschi\Federico-Bernardeschi  33.0   it ITA   LM  26-282
# 4               Federico Chiesa\Federico-Chiesa  22.0   it ITA   LM  23-030
# 5               Weston McKennie\Weston-McKennie  14.0   us USA   RM  22-088
# 6             Dejan Kulusevski\Dejan-Kulusevski  44.0   se SWE   RM  20-213
# 7                       Arthur Melo\Arthur-Melo   5.0   br BRA   DM  24-104
# 8                     Aaron Ramsey\Aaron-Ramsey   8.0  wal WAL   DM  29-334
# 9           Rodrigo Bentancur\Rodrigo-Bentancur  30.0   uy URU   DM  23-172
# 10                  Adrien Rabiot\Adrien-Rabiot  25.0   fr FRA   DM  25-235
# 11                      Alex Sandro\Alex-Sandro  12.0   br BRA   LB  29-303
# 12            Matthijs de Ligt\Matthijs-de-Ligt   4.0   nl NED   CB  21-104
# 13                                Danilo\Danilo  13.0   br BRA   CB  29-132
# 14                  Juan Cuadrado\Juan-Cuadrado  16.0   co COL   RB  32-182
# 15          Wojciech Szczęsny\Wojciech-Szczesny   1.0   pl POL   GK  30-220
# 16                                   16 Players   NaN      NaN  NaN     NaN
#
#     Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  CrdR  Touches  Press  Tkl  Int  \
# 0    90    1    0   0      0   2    1     0     0       48      7    0    0
# 1    61    0    0   0      0   3    2     0     0       48      9    0    0
# 2    29    1    0   0      0   2    1     0     0        9      5    0    0
# 3    61    0    0   0      0   3    0     0     0       37      3    1    0
# 4    29    0    0   0      0   0    0     1     0       25      5    0    1
# 5    61    0    0   0      0   0    0     0     0       33     18    2    1
# 6    29    0    0   0      0   1    0     0     0       11      9    0    0
# 7    82    0    0   0      0   2    0     0     0      104     14    0    0
# 8     8    0    0   0      0   0    0     0     0       18      2    0    0
# 9    82    0    0   0      0   3    1     0     0       73     12    4    1
# 10    8    0    0   0      0   0    0     0     0        8      2    0    1
# 11   90    0    0   0      0   1    0     0     0      110     18    4    3
# 12   90    0    0   0      0   0    0     0     0      110      9    1    0
# 13   90    0    0   0      0   1    1     1     0      114      3    0    1
# 14   90    0    2   0      0   1    0     0     0      110     10    4    1
# 15   90    0    0   0      0   0    0     0     0       20      0    0    0
# 16  990    2    2   0      0  19    6     2     0      878    126   16    9
#
#     Blocks   xG  npxG   xA  SCA  GCA  Cmp  Att   Cmp%  PrgDist  Carries  \
# 0        1  0.1   0.1  0.2    4    1   30   35   85.7       91       35
# 1        0  0.2   0.2  0.1    4    0   33   40   82.5       76       35
# 2        1  0.4   0.4  0.0    0    0    5    5  100.0       27        6
# 3        1  0.1   0.1  0.0    2    0   22   30   73.3       87       33
# 4        0  0.0   0.0  0.2    1    0   12   20   60.0       41       16
# 5        1  0.0   0.0  0.0    0    0   21   27   77.8       49       17
# 6        1  0.0   0.0  0.0    1    0    3    7   42.9       11       10
# 7        1  0.1   0.1  0.1    3    0   87   96   90.6      463       83
# 8        0  0.0   0.0  0.0    0    0   14   18   77.8        4       10
# 9        2  0.1   0.1  0.0    1    0   54   64   84.4      258       53
# 10       0  0.0   0.0  0.0    0    0    8    8  100.0       16        6
# 11       5  0.0   0.0  0.0    2    0   85   97   87.6      335       76
# 12       3  0.0   0.0  0.0    0    0   96  102   94.1      530       80
# 13       0  0.0   0.0  0.0    2    1   98  108   90.7      643       83
# 14       2  0.1   0.1  0.3   10    2   79   97   81.4      409       80
# 15       0  0.0   0.0  0.0    0    0   20   20  100.0      257       10
# 16      18  1.1   1.1  0.9   30    4  667  774   86.2     3297      633
#
#     PrgDist.1  Succ  Att.1
# 0          63     3      6
# 1          49     0      1
# 2          18     2      2
# 3         117     2      3
# 4          33     0      1
# 5          28     1      1
# 6          25     1      1
# 7         226     1      2
# 8           9     0      0
# 9          84     2      2
# 10         34     0      0
# 11        192     3      3
# 12        262     0      0
# 13        233     0      0
# 14        187     3      4
# 15         19     0      0
# 16       1579    18     26

# %%
team_total = df.loc[16].copy
team_total
# Out:
# <bound method NDFrame.copy of Player       16 Players
# #                   NaN
# Nation              NaN
# Pos                 NaN
# Age                 NaN
# Min                 990
# Gls                   2
# Ast                   2
# PK                    0
# PKatt                 0
# Sh                   19
# SoT                   6
# CrdY                  2
# CrdR                  0
# Touches             878
# Press               126
# Tkl                  16
# Int                   9
# Blocks               18
# xG                  1.1
# npxG                1.1
# xA                  0.9
# SCA                  30
# GCA                   4
# Cmp                 667
# Att                 774
# Cmp%               86.2
# PrgDist            3297
# Carries             633
# PrgDist.1          1579
# Succ                 18
# Att.1                26
# Name: 16, dtype: object>

# %%
df = df.drop(16)

# %%
for key, name in enumerate(df.Player):
    if '-' in name:
        splitting = name.split('-')
        df.Player[key] = splitting[1]
    else: 
        df.Player[key] = name
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Age']
# Out:
# 0     35-293
# 1     27-009
# 2     28-032
# 3     26-282
# 4     23-030
# 5     22-088
# 6     20-213
# 7     24-104
# 8     29-334
# 9     23-172
# 10    25-235
# 11    29-303
# 12    21-104
# 13    29-132
# 14    32-182
# 15    30-220
# Name: Age, dtype: object

# %%
for key, age in enumerate(df.Age):
    splitting = age.split('-')
    df.Age[key] = splitting[0]
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.Age = df.Age.astype(int)

# %%
df_age = df[['Player', 'Age']]

# %%
df_age.dtypes
# Out:
# Player    object
# Age        int64
# dtype: object

# %%
df_age.describe()
# Out:
#              Age
# count  16.000000
# mean   26.437500
# std     4.178816
# min    20.000000
# 25%    23.000000
# 50%    26.500000
# 75%    29.000000
# max    35.000000

# %%
ax = sns.boxplot( y=df["Age"] )
ax = sns.swarmplot( y="Age", data=df_age, color="red", size=10)

# %%
df_sum = df[['Player', 'Sh', 'SCA', 'Touches', 'PrgDist', 'PrgDist.1', 'Press', 'Tkl', 'Int', 'Blocks']]
df_sum
# Out:
#            Player  Sh  SCA  Touches  PrgDist  PrgDist.1  Press  Tkl  Int  \
# 0         Ronaldo   2    4       48       91         63      7    0    0
# 1          Dybala   3    4       48       76         49      9    0    0
# 2          Morata   2    0        9       27         18      5    0    0
# 3    Bernardeschi   3    2       37       87        117      3    1    0
# 4          Chiesa   0    1       25       41         33      5    0    1
# 5        McKennie   0    0       33       49         28     18    2    1
# 6      Kulusevski   1    1       11       11         25      9    0    0
# 7            Melo   2    3      104      463        226     14    0    0
# 8          Ramsey   0    0       18        4          9      2    0    0
# 9       Bentancur   3    1       73      258         84     12    4    1
# 10         Rabiot   0    0        8       16         34      2    0    1
# 11         Sandro   1    2      110      335        192     18    4    3
# 12             de   0    0      110      530        262      9    1    0
# 13  Danilo\Danilo   1    2      114      643        233      3    0    1
# 14       Cuadrado   1   10      110      409        187     10    4    1
# 15       Szczesny   0    0       20      257         19      0    0    0
#
#     Blocks
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# 5        1
# 6        1
# 7        1
# 8        0
# 9        2
# 10       0
# 11       5
# 12       3
# 13       0
# 14       2
# 15       0

# %%
df_sum.columns = ['Player', 'Shots', 'SCA', 'Touches', 'PassPrgDist', 'CarryPrgDist','Press', 'Tackled', 'Interceptions', 'Blocks']
df_sum = df_sum.set_index('Player')

# %%
df_trans = df_sum.T # or df1.transpose()

df_trans
# Out:
# Player         Ronaldo  Dybala  Morata  Bernardeschi  Chiesa  McKennie  \
# Shots                2       3       2             3       0         0
# SCA                  4       4       0             2       1         0
# Touches             48      48       9            37      25        33
# PassPrgDist         91      76      27            87      41        49
# CarryPrgDist        63      49      18           117      33        28
# Press                7       9       5             3       5        18
# Tackled              0       0       0             1       0         2
# Interceptions        0       0       0             0       1         1
# Blocks               1       0       1             1       0         1
#
# Player         Kulusevski  Melo  Ramsey  Bentancur  Rabiot  Sandro   de  \
# Shots                   1     2       0          3       0       1    0
# SCA                     1     3       0          1       0       2    0
# Touches                11   104      18         73       8     110  110
# PassPrgDist            11   463       4        258      16     335  530
# CarryPrgDist           25   226       9         84      34     192  262
# Press                   9    14       2         12       2      18    9
# Tackled                 0     0       0          4       0       4    1
# Interceptions           0     0       0          1       1       3    0
# Blocks                  1     1       0          2       0       5    3
#
# Player         Danilo\Danilo  Cuadrado  Szczesny
# Shots                      1         1         0
# SCA                        2        10         0
# Touches                  114       110        20
# PassPrgDist              643       409       257
# CarryPrgDist             233       187        19
# Press                      3        10         0
# Tackled                    0         4         0
# Interceptions              1         1         0
# Blocks                     0         2         0

# %%
df_sum_copy = df_sum.copy()
df_sum_copy = df_sum_copy.astype(float).round(2)
df_sum_copy
# Out:
#                Shots   SCA  Touches  PassPrgDist  CarryPrgDist  Press  \
# Player
# Ronaldo          2.0   4.0     48.0         91.0          63.0    7.0
# Dybala           3.0   4.0     48.0         76.0          49.0    9.0
# Morata           2.0   0.0      9.0         27.0          18.0    5.0
# Bernardeschi     3.0   2.0     37.0         87.0         117.0    3.0
# Chiesa           0.0   1.0     25.0         41.0          33.0    5.0
# McKennie         0.0   0.0     33.0         49.0          28.0   18.0
# Kulusevski       1.0   1.0     11.0         11.0          25.0    9.0
# Melo             2.0   3.0    104.0        463.0         226.0   14.0
# Ramsey           0.0   0.0     18.0          4.0           9.0    2.0
# Bentancur        3.0   1.0     73.0        258.0          84.0   12.0
# Rabiot           0.0   0.0      8.0         16.0          34.0    2.0
# Sandro           1.0   2.0    110.0        335.0         192.0   18.0
# de               0.0   0.0    110.0        530.0         262.0    9.0
# Danilo\Danilo    1.0   2.0    114.0        643.0         233.0    3.0
# Cuadrado         1.0  10.0    110.0        409.0         187.0   10.0
# Szczesny         0.0   0.0     20.0        257.0          19.0    0.0
#
#                Tackled  Interceptions  Blocks
# Player
# Ronaldo            0.0            0.0     1.0
# Dybala             0.0            0.0     0.0
# Morata             0.0            0.0     1.0
# Bernardeschi       1.0            0.0     1.0
# Chiesa             0.0            1.0     0.0
# McKennie           2.0            1.0     1.0
# Kulusevski         0.0            0.0     1.0
# Melo               0.0            0.0     1.0
# Ramsey             0.0            0.0     0.0
# Bentancur          4.0            1.0     2.0
# Rabiot             0.0            1.0     0.0
# Sandro             4.0            3.0     5.0
# de                 1.0            0.0     3.0
# Danilo\Danilo      0.0            1.0     0.0
# Cuadrado           4.0            1.0     2.0
# Szczesny           0.0            0.0     0.0

# %%
df_columns = df_sum_copy.columns
df_columns
# Out:
# Index(['Shots', 'SCA', 'Touches', 'PassPrgDist', 'CarryPrgDist', 'Press',
#        'Tackled', 'Interceptions', 'Blocks'],
#       dtype='object')

# %%
for key, val in enumerate(df_sum_copy):
    df_sum_copy[f'{val}'] = df_sum_copy[f'{val}']/df_sum_copy[f'{val}'].max()

df_sum_copy = df_sum_copy.round(2)
df_sum_copy
# Out:
#                Shots  SCA  Touches  PassPrgDist  CarryPrgDist  Press  Tackled  \
# Player
# Ronaldo         0.67  0.4     0.42         0.14          0.24   0.39     0.00
# Dybala          1.00  0.4     0.42         0.12          0.19   0.50     0.00
# Morata          0.67  0.0     0.08         0.04          0.07   0.28     0.00
# Bernardeschi    1.00  0.2     0.32         0.14          0.45   0.17     0.25
# Chiesa          0.00  0.1     0.22         0.06          0.13   0.28     0.00
# McKennie        0.00  0.0     0.29         0.08          0.11   1.00     0.50
# Kulusevski      0.33  0.1     0.10         0.02          0.10   0.50     0.00
# Melo            0.67  0.3     0.91         0.72          0.86   0.78     0.00
# Ramsey          0.00  0.0     0.16         0.01          0.03   0.11     0.00
# Bentancur       1.00  0.1     0.64         0.40          0.32   0.67     1.00
# Rabiot          0.00  0.0     0.07         0.02          0.13   0.11     0.00
# Sandro          0.33  0.2     0.96         0.52          0.73   1.00     1.00
# de              0.00  0.0     0.96         0.82          1.00   0.50     0.25
# Danilo\Danilo   0.33  0.2     1.00         1.00          0.89   0.17     0.00
# Cuadrado        0.33  1.0     0.96         0.64          0.71   0.56     1.00
# Szczesny        0.00  0.0     0.18         0.40          0.07   0.00     0.00
#
#                Interceptions  Blocks
# Player
# Ronaldo                 0.00     0.2
# Dybala                  0.00     0.0
# Morata                  0.00     0.2
# Bernardeschi            0.00     0.2
# Chiesa                  0.33     0.0
# McKennie                0.33     0.2
# Kulusevski              0.00     0.2
# Melo                    0.00     0.2
# Ramsey                  0.00     0.0
# Bentancur               0.33     0.4
# Rabiot                  0.33     0.0
# Sandro                  1.00     1.0
# de                      0.00     0.6
# Danilo\Danilo           0.33     0.0
# Cuadrado                0.33     0.4
# Szczesny                0.00     0.0

# %%
 
# number of variable
categories=list(df_sum_copy)
N = len(categories)
categories
# Out:
# ['Shots',
#  'SCA',
#  'Touches',
#  'PassPrgDist',
#  'CarryPrgDist',
#  'Press',
#  'Tackled',
#  'Interceptions',
#  'Blocks']

# %%
for i in range(len(df_sum_copy.index)):    
# But we need to repeat the first value to close the circular graph:
    values=df_sum_copy.iloc[i].values.flatten().tolist()
    values += values[:1]
     
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    plt.figure()
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
    plt.ylim(0,1)

    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')
    plt.title(str(df_sum_copy.index[i]), x=.5, y=1)

    # Fill area
    ax.fill(angles, values, 'b', alpha=0.1)
    plt.savefig((str(df_sum_copy.index[i]) + ".png"))
plt.show()
