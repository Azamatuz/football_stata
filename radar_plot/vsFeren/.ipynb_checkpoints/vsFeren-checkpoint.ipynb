# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
# Libraries
from math import pi

# %%
df = pd.read_csv('vsCagliari.csv', header=1)
df
# Out:
#                                          Player     #  Nation  Pos     Age  \
# 0           Cristiano Ronaldo\Cristiano-Ronaldo   7.0  pt POR   FW  35-290
# 1                   Álvaro Morata\Alvaro-Morata   9.0  es ESP   FW  28-029
# 2                     Paulo Dybala\Paulo-Dybala  10.0  ar ARG   FW  27-006
# 3   Federico Bernardeschi\Federico-Bernardeschi  33.0  it ITA   LM  26-279
# 4             Dejan Kulusevski\Dejan-Kulusevski  44.0  se SWE   RM  20-210
# 5               Federico Chiesa\Federico-Chiesa  22.0  it ITA   RM  23-027
# 6                   Adrien Rabiot\Adrien-Rabiot  25.0  fr FRA   DM  25-232
# 7               Weston McKennie\Weston-McKennie  14.0  us USA   DM  22-085
# 8                       Arthur Melo\Arthur-Melo   5.0  br BRA   DM  24-101
# 9           Rodrigo Bentancur\Rodrigo-Bentancur  30.0  uy URU   DM  23-169
# 10                                Danilo\Danilo  13.0  br BRA   LB  29-129
# 11                      Alex Sandro\Alex-Sandro  12.0  br BRA   LB  29-300
# 12            Matthijs de Ligt\Matthijs-de-Ligt   4.0  nl NED   CB  21-101
# 13                  Merih Demiral\Merih-Demiral  28.0  tr TUR   CB  22-261
# 14                  Juan Cuadrado\Juan-Cuadrado  16.0  co COL   RB  32-179
# 15            Gianluigi Buffon\Gianluigi-Buffon  77.0  it ITA   GK  42-298
# 16                                   16 Players   NaN     NaN  NaN     NaN
#
#     Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  CrdR  Touches  Press  Tkl  Int  \
# 0    90    2    0   0      0   6    2     0     0       85      6    2    0
# 1    68    0    1   0      0   2    0     0     0       38     17    2    1
# 2    22    0    0   0      0   2    0     0     0       31      4    1    0
# 3    90    0    0   0      0   4    3     0     0       63     13    2    0
# 4    85    0    0   0      0   4    0     0     0       55     19    2    2
# 5     5    0    0   0      0   0    0     0     0        5      2    0    0
# 6    68    0    0   0      0   1    1     1     0       64     17    2    0
# 7    22    0    0   0      0   1    0     0     0       19     11    1    1
# 8    84    0    0   0      0   0    0     1     0      103     14    3    4
# 9     6    0    0   0      0   0    0     0     0        6      4    0    0
# 10   85    0    0   0      0   0    0     1     0       83     11    1    3
# 11    5    0    0   0      0   0    0     0     0        9      2    1    0
# 12   90    0    0   0      0   1    0     0     0       82      7    3    0
# 13   90    0    1   0      0   2    0     0     0       95      4    2    0
# 14   90    0    0   0      0   1    0     0     0      119     14    3    1
# 15   90    0    0   0      0   0    0     0     0       33      0    0    0
# 16  990    2    2   0      0  24    6     3     0      890    145   25   12
#
#     Blocks   xG  npxG   xA  SCA  GCA  Cmp  Att   Cmp%  PrgDist  Carries  \
# 0        0  0.6   0.6  0.4    5    0   63   74   85.1      182       59
# 1        1  0.3   0.3  0.1    3    1   19   25   76.0       48       25
# 2        1  0.2   0.2  0.0    0    0   23   25   92.0       92       22
# 3        0  0.4   0.4  0.4    7    1   48   55   87.3      250       49
# 4        0  0.3   0.3  0.1    6    0   35   40   87.5      145       39
# 5        0  0.0   0.0  0.0    0    0    4    4  100.0        8        5
# 6        2  0.0   0.0  0.0    1    0   48   54   88.9      239       39
# 7        0  0.1   0.1  0.0    1    0   13   16   81.3       22        6
# 8        0  0.0   0.0  0.0    1    0   96  100   96.0      490       79
# 9        0  0.0   0.0  0.0    0    0    5    6   83.3       22        4
# 10       0  0.0   0.0  0.0    1    0   70   81   86.4      485       67
# 11       0  0.0   0.0  0.0    1    0    6    8   75.0       23        7
# 12       2  0.1   0.1  0.0    1    0   68   75   90.7      433       53
# 13       0  0.2   0.2  0.0    2    1   88   89   98.9      456       66
# 14       2  0.0   0.0  0.5    8    0   96  106   90.6      731       80
# 15       0  0.0   0.0  0.0    0    0   30   33   90.9      257       22
# 16       8  2.2   2.2  1.6   37    3  712  791   90.0     3883      622
#
#     PrgDist.1  Succ  Att.1
# 0         360     1      1
# 1         106     1      2
# 2          92     0      1
# 3         117     5      7
# 4         158     1      1
# 5           6     1      1
# 6         148     0      0
# 7          28     0      0
# 8          71     1      2
# 9           0     0      0
# 10        194     0      0
# 11         10     0      0
# 12         99     0      0
# 13        167     0      0
# 14        254     2      4
# 15         25     0      0
# 16       1835    12     19

# %%
df = df.drop(16)

# %%
for key, name in enumerate(df.Player):
    if '-' in name:
        splitting = name.split('-')
        df.Player[key] = splitting[1]
    else: 
        df.Player[key] = name
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Age']
# Out:
# 0     35-290
# 1     28-029
# 2     27-006
# 3     26-279
# 4     20-210
# 5     23-027
# 6     25-232
# 7     22-085
# 8     24-101
# 9     23-169
# 10    29-129
# 11    29-300
# 12    21-101
# 13    22-261
# 14    32-179
# 15    42-298
# Name: Age, dtype: object

# %%
for key, age in enumerate(df.Age):
    splitting = age.split('-')
    df.Age[key] = splitting[0]
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.Age = df.Age.astype(int)

# %%
df_age = df[['Player', 'Age']]

# %%
df_age.dtypes
# Out:
# Player    object
# Age        int64
# dtype: object

# %%
df_age.describe()
# Out:
#              Age
# count  16.000000
# mean   26.750000
# std     5.790797
# min    20.000000
# 25%    22.750000
# 50%    25.500000
# 75%    29.000000
# max    42.000000

# %%
ax = sns.boxplot( y=df["Age"] )
ax = sns.swarmplot( y="Age", data=df_age, color="red", size=10)

# %%
df_sum = df[['Player', 'Sh', 'SCA', 'Touches', 'PrgDist', 'PrgDist.1', 'Press', 'Tkl', 'Int', 'Blocks']]
df_sum
# Out:
#            Player  Sh  SCA  Touches  PrgDist  PrgDist.1  Press  Tkl  Int  \
# 0         Ronaldo   6    5       85      182        360      6    2    0
# 1          Morata   2    3       38       48        106     17    2    1
# 2          Dybala   2    0       31       92         92      4    1    0
# 3    Bernardeschi   4    7       63      250        117     13    2    0
# 4      Kulusevski   4    6       55      145        158     19    2    2
# 5          Chiesa   0    0        5        8          6      2    0    0
# 6          Rabiot   1    1       64      239        148     17    2    0
# 7        McKennie   1    1       19       22         28     11    1    1
# 8            Melo   0    1      103      490         71     14    3    4
# 9       Bentancur   0    0        6       22          0      4    0    0
# 10  Danilo\Danilo   0    1       83      485        194     11    1    3
# 11         Sandro   0    1        9       23         10      2    1    0
# 12             de   1    1       82      433         99      7    3    0
# 13        Demiral   2    2       95      456        167      4    2    0
# 14       Cuadrado   1    8      119      731        254     14    3    1
# 15         Buffon   0    0       33      257         25      0    0    0
#
#     Blocks
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0
# 5        0
# 6        2
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       2
# 13       0
# 14       2
# 15       0

# %%
df_sum.columns = ['Player', 'Shots', 'SCA', 'Touches', 'PassPrgDist', 'CarryPrgDist','Press', 'Tackled', 'Interceptions', 'Blocks']
df_sum = df_sum.set_index('Player')

# %%
df_trans = df_sum.T # or df1.transpose()

df_trans
# Out:
# Player         Ronaldo  Morata  Dybala  Bernardeschi  Kulusevski  Chiesa  \
# Shots                6       2       2             4           4       0
# SCA                  5       3       0             7           6       0
# Touches             85      38      31            63          55       5
# PassPrgDist        182      48      92           250         145       8
# CarryPrgDist       360     106      92           117         158       6
# Press                6      17       4            13          19       2
# Tackled              2       2       1             2           2       0
# Interceptions        0       1       0             0           2       0
# Blocks               0       1       1             0           0       0
#
# Player         Rabiot  McKennie  Melo  Bentancur  Danilo\Danilo  Sandro   de  \
# Shots               1         1     0          0              0       0    1
# SCA                 1         1     1          0              1       1    1
# Touches            64        19   103          6             83       9   82
# PassPrgDist       239        22   490         22            485      23  433
# CarryPrgDist      148        28    71          0            194      10   99
# Press              17        11    14          4             11       2    7
# Tackled             2         1     3          0              1       1    3
# Interceptions       0         1     4          0              3       0    0
# Blocks              2         0     0          0              0       0    2
#
# Player         Demiral  Cuadrado  Buffon
# Shots                2         1       0
# SCA                  2         8       0
# Touches             95       119      33
# PassPrgDist        456       731     257
# CarryPrgDist       167       254      25
# Press                4        14       0
# Tackled              2         3       0
# Interceptions        0         1       0
# Blocks               0         2       0

# %%
df_sum_copy = df_sum.copy()
df_sum_copy = df_sum_copy.astype(float).round(2)
df_sum_copy
# Out:
#                Shots  SCA  Touches  PassPrgDist  CarryPrgDist  Press  Tackled  \
# Player
# Ronaldo          6.0  5.0     85.0        182.0         360.0    6.0      2.0
# Morata           2.0  3.0     38.0         48.0         106.0   17.0      2.0
# Dybala           2.0  0.0     31.0         92.0          92.0    4.0      1.0
# Bernardeschi     4.0  7.0     63.0        250.0         117.0   13.0      2.0
# Kulusevski       4.0  6.0     55.0        145.0         158.0   19.0      2.0
# Chiesa           0.0  0.0      5.0          8.0           6.0    2.0      0.0
# Rabiot           1.0  1.0     64.0        239.0         148.0   17.0      2.0
# McKennie         1.0  1.0     19.0         22.0          28.0   11.0      1.0
# Melo             0.0  1.0    103.0        490.0          71.0   14.0      3.0
# Bentancur        0.0  0.0      6.0         22.0           0.0    4.0      0.0
# Danilo\Danilo    0.0  1.0     83.0        485.0         194.0   11.0      1.0
# Sandro           0.0  1.0      9.0         23.0          10.0    2.0      1.0
# de               1.0  1.0     82.0        433.0          99.0    7.0      3.0
# Demiral          2.0  2.0     95.0        456.0         167.0    4.0      2.0
# Cuadrado         1.0  8.0    119.0        731.0         254.0   14.0      3.0
# Buffon           0.0  0.0     33.0        257.0          25.0    0.0      0.0
#
#                Interceptions  Blocks
# Player
# Ronaldo                  0.0     0.0
# Morata                   1.0     1.0
# Dybala                   0.0     1.0
# Bernardeschi             0.0     0.0
# Kulusevski               2.0     0.0
# Chiesa                   0.0     0.0
# Rabiot                   0.0     2.0
# McKennie                 1.0     0.0
# Melo                     4.0     0.0
# Bentancur                0.0     0.0
# Danilo\Danilo            3.0     0.0
# Sandro                   0.0     0.0
# de                       0.0     2.0
# Demiral                  0.0     0.0
# Cuadrado                 1.0     2.0
# Buffon                   0.0     0.0

# %%
df_columns = df_sum_copy.columns
df_columns
# Out:
# Index(['Shots', 'SCA', 'Touches', 'PassPrgDist', 'CarryPrgDist', 'Press',
#        'Tackled', 'Interceptions', 'Blocks'],
#       dtype='object')

# %%
#f"Shepherd {shepherd} is {age} years old."
for key, val in enumerate(df_sum_copy):
    df_sum_copy[f'{val}'] = df_sum_copy[f'{val}']/df_sum_copy[f'{val}'].max()

df_sum_copy = df_sum_copy.round(2)
df_sum_copy
# Out:
#                Shots   SCA  Touches  PassPrgDist  CarryPrgDist  Press  \
# Player
# Ronaldo         1.00  0.62     0.71         0.25          1.00   0.32
# Morata          0.33  0.38     0.32         0.07          0.29   0.89
# Dybala          0.33  0.00     0.26         0.13          0.26   0.21
# Bernardeschi    0.67  0.88     0.53         0.34          0.32   0.68
# Kulusevski      0.67  0.75     0.46         0.20          0.44   1.00
# Chiesa          0.00  0.00     0.04         0.01          0.02   0.11
# Rabiot          0.17  0.12     0.54         0.33          0.41   0.89
# McKennie        0.17  0.12     0.16         0.03          0.08   0.58
# Melo            0.00  0.12     0.87         0.67          0.20   0.74
# Bentancur       0.00  0.00     0.05         0.03          0.00   0.21
# Danilo\Danilo   0.00  0.12     0.70         0.66          0.54   0.58
# Sandro          0.00  0.12     0.08         0.03          0.03   0.11
# de              0.17  0.12     0.69         0.59          0.28   0.37
# Demiral         0.33  0.25     0.80         0.62          0.46   0.21
# Cuadrado        0.17  1.00     1.00         1.00          0.71   0.74
# Buffon          0.00  0.00     0.28         0.35          0.07   0.00
#
#                Tackled  Interceptions  Blocks
# Player
# Ronaldo           0.67           0.00     0.0
# Morata            0.67           0.25     0.5
# Dybala            0.33           0.00     0.5
# Bernardeschi      0.67           0.00     0.0
# Kulusevski        0.67           0.50     0.0
# Chiesa            0.00           0.00     0.0
# Rabiot            0.67           0.00     1.0
# McKennie          0.33           0.25     0.0
# Melo              1.00           1.00     0.0
# Bentancur         0.00           0.00     0.0
# Danilo\Danilo     0.33           0.75     0.0
# Sandro            0.33           0.00     0.0
# de                1.00           0.00     1.0
# Demiral           0.67           0.00     0.0
# Cuadrado          1.00           0.25     1.0
# Buffon            0.00           0.00     0.0

# %%
 
# number of variable
categories=list(df_sum_copy)
N = len(categories)
categories
# Out:
# ['Shots',
#  'SCA',
#  'Touches',
#  'PassPrgDist',
#  'CarryPrgDist',
#  'Press',
#  'Tackled',
#  'Interceptions',
#  'Blocks']

# %%
for i in range(len(df_sum_copy.index)):    
# But we need to repeat the first value to close the circular graph:
    values=df_sum_copy.iloc[i].values.flatten().tolist()
    values += values[:1]
     
    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    plt.figure()
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
    plt.ylim(0,1)

    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')
    plt.title(str(df_sum_copy.index[i]), x=.5, y=1)

    # Fill area
    ax.fill(angles, values, 'b', alpha=0.1)
    plt.savefig((str(df_sum_copy.index[i]) + ".png"))
plt.show()
