# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)
from math import pi

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
current_df = pd.read_csv('vsFeren.csv', header=1)
current_df
# Out:
#                                          Player     #   Nation  Pos     Age  \
# 0           Cristiano Ronaldo\Cristiano-Ronaldo   7.0   pt POR   FW  35-293
# 1                     Paulo Dybala\Paulo-Dybala  10.0   ar ARG   FW  27-009
# 2                   Álvaro Morata\Alvaro-Morata   9.0   es ESP   FW  28-032
# 3   Federico Bernardeschi\Federico-Bernardeschi  33.0   it ITA   LM  26-282
# 4               Federico Chiesa\Federico-Chiesa  22.0   it ITA   LM  23-030
# 5               Weston McKennie\Weston-McKennie  14.0   us USA   RM  22-088
# 6             Dejan Kulusevski\Dejan-Kulusevski  44.0   se SWE   RM  20-213
# 7                       Arthur Melo\Arthur-Melo   5.0   br BRA   DM  24-104
# 8                     Aaron Ramsey\Aaron-Ramsey   8.0  wal WAL   DM  29-334
# 9           Rodrigo Bentancur\Rodrigo-Bentancur  30.0   uy URU   DM  23-172
# 10                  Adrien Rabiot\Adrien-Rabiot  25.0   fr FRA   DM  25-235
# 11                      Alex Sandro\Alex-Sandro  12.0   br BRA   LB  29-303
# 12            Matthijs de Ligt\Matthijs-de-Ligt   4.0   nl NED   CB  21-104
# 13                                Danilo\Danilo  13.0   br BRA   CB  29-132
# 14                  Juan Cuadrado\Juan-Cuadrado  16.0   co COL   RB  32-182
# 15          Wojciech Szczęsny\Wojciech-Szczesny   1.0   pl POL   GK  30-220
# 16                                   16 Players   NaN      NaN  NaN     NaN
#
#     Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  CrdR  Touches  Press  Tkl  Int  \
# 0    90    1    0   0      0   2    1     0     0       48      7    0    0
# 1    61    0    0   0      0   3    2     0     0       48      9    0    0
# 2    29    1    0   0      0   2    1     0     0        9      5    0    0
# 3    61    0    0   0      0   3    0     0     0       37      3    1    0
# 4    29    0    0   0      0   0    0     1     0       25      5    0    1
# 5    61    0    0   0      0   0    0     0     0       33     18    2    1
# 6    29    0    0   0      0   1    0     0     0       11      9    0    0
# 7    82    0    0   0      0   2    0     0     0      104     14    0    0
# 8     8    0    0   0      0   0    0     0     0       18      2    0    0
# 9    82    0    0   0      0   3    1     0     0       73     12    4    1
# 10    8    0    0   0      0   0    0     0     0        8      2    0    1
# 11   90    0    0   0      0   1    0     0     0      110     18    4    3
# 12   90    0    0   0      0   0    0     0     0      110      9    1    0
# 13   90    0    0   0      0   1    1     1     0      114      3    0    1
# 14   90    0    2   0      0   1    0     0     0      110     10    4    1
# 15   90    0    0   0      0   0    0     0     0       20      0    0    0
# 16  990    2    2   0      0  19    6     2     0      878    126   16    9
#
#     Blocks   xG  npxG   xA  SCA  GCA  Cmp  Att   Cmp%  PrgDist  Carries  \
# 0        1  0.1   0.1  0.2    4    1   30   35   85.7       91       35
# 1        0  0.2   0.2  0.1    4    0   33   40   82.5       76       35
# 2        1  0.4   0.4  0.0    0    0    5    5  100.0       27        6
# 3        1  0.1   0.1  0.0    2    0   22   30   73.3       87       33
# 4        0  0.0   0.0  0.2    1    0   12   20   60.0       41       16
# 5        1  0.0   0.0  0.0    0    0   21   27   77.8       49       17
# 6        1  0.0   0.0  0.0    1    0    3    7   42.9       11       10
# 7        1  0.1   0.1  0.1    3    0   87   96   90.6      463       83
# 8        0  0.0   0.0  0.0    0    0   14   18   77.8        4       10
# 9        2  0.1   0.1  0.0    1    0   54   64   84.4      258       53
# 10       0  0.0   0.0  0.0    0    0    8    8  100.0       16        6
# 11       5  0.0   0.0  0.0    2    0   85   97   87.6      335       76
# 12       3  0.0   0.0  0.0    0    0   96  102   94.1      530       80
# 13       0  0.0   0.0  0.0    2    1   98  108   90.7      643       83
# 14       2  0.1   0.1  0.3   10    2   79   97   81.4      409       80
# 15       0  0.0   0.0  0.0    0    0   20   20  100.0      257       10
# 16      18  1.1   1.1  0.9   30    4  667  774   86.2     3297      633
#
#     PrgDist.1  Succ  Att.1
# 0          63     3      6
# 1          49     0      1
# 2          18     2      2
# 3         117     2      3
# 4          33     0      1
# 5          28     1      1
# 6          25     1      1
# 7         226     1      2
# 8           9     0      0
# 9          84     2      2
# 10         34     0      0
# 11        192     3      3
# 12        262     0      0
# 13        233     0      0
# 14        187     3      4
# 15         19     0      0
# 16       1579    18     26

# %%
vsFeren = current_df[-1:].copy

# %%
prev_df = pd.read_csv('vsCagliari.csv', header=1)
prev_df
# Out:
#                                          Player     #  Nation  Pos     Age  \
# 0           Cristiano Ronaldo\Cristiano-Ronaldo   7.0  pt POR   FW  35-290
# 1                   Álvaro Morata\Alvaro-Morata   9.0  es ESP   FW  28-029
# 2                     Paulo Dybala\Paulo-Dybala  10.0  ar ARG   FW  27-006
# 3   Federico Bernardeschi\Federico-Bernardeschi  33.0  it ITA   LM  26-279
# 4             Dejan Kulusevski\Dejan-Kulusevski  44.0  se SWE   RM  20-210
# 5               Federico Chiesa\Federico-Chiesa  22.0  it ITA   RM  23-027
# 6                   Adrien Rabiot\Adrien-Rabiot  25.0  fr FRA   DM  25-232
# 7               Weston McKennie\Weston-McKennie  14.0  us USA   DM  22-085
# 8                       Arthur Melo\Arthur-Melo   5.0  br BRA   DM  24-101
# 9           Rodrigo Bentancur\Rodrigo-Bentancur  30.0  uy URU   DM  23-169
# 10                                Danilo\Danilo  13.0  br BRA   LB  29-129
# 11                      Alex Sandro\Alex-Sandro  12.0  br BRA   LB  29-300
# 12            Matthijs de Ligt\Matthijs-de-Ligt   4.0  nl NED   CB  21-101
# 13                  Merih Demiral\Merih-Demiral  28.0  tr TUR   CB  22-261
# 14                  Juan Cuadrado\Juan-Cuadrado  16.0  co COL   RB  32-179
# 15            Gianluigi Buffon\Gianluigi-Buffon  77.0  it ITA   GK  42-298
# 16                                   16 Players   NaN     NaN  NaN     NaN
#
#     Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  CrdR  Touches  Press  Tkl  Int  \
# 0    90    2    0   0      0   6    2     0     0       85      6    2    0
# 1    68    0    1   0      0   2    0     0     0       38     17    2    1
# 2    22    0    0   0      0   2    0     0     0       31      4    1    0
# 3    90    0    0   0      0   4    3     0     0       63     13    2    0
# 4    85    0    0   0      0   4    0     0     0       55     19    2    2
# 5     5    0    0   0      0   0    0     0     0        5      2    0    0
# 6    68    0    0   0      0   1    1     1     0       64     17    2    0
# 7    22    0    0   0      0   1    0     0     0       19     11    1    1
# 8    84    0    0   0      0   0    0     1     0      103     14    3    4
# 9     6    0    0   0      0   0    0     0     0        6      4    0    0
# 10   85    0    0   0      0   0    0     1     0       83     11    1    3
# 11    5    0    0   0      0   0    0     0     0        9      2    1    0
# 12   90    0    0   0      0   1    0     0     0       82      7    3    0
# 13   90    0    1   0      0   2    0     0     0       95      4    2    0
# 14   90    0    0   0      0   1    0     0     0      119     14    3    1
# 15   90    0    0   0      0   0    0     0     0       33      0    0    0
# 16  990    2    2   0      0  24    6     3     0      890    145   25   12
#
#     Blocks   xG  npxG   xA  SCA  GCA  Cmp  Att   Cmp%  PrgDist  Carries  \
# 0        0  0.6   0.6  0.4    5    0   63   74   85.1      182       59
# 1        1  0.3   0.3  0.1    3    1   19   25   76.0       48       25
# 2        1  0.2   0.2  0.0    0    0   23   25   92.0       92       22
# 3        0  0.4   0.4  0.4    7    1   48   55   87.3      250       49
# 4        0  0.3   0.3  0.1    6    0   35   40   87.5      145       39
# 5        0  0.0   0.0  0.0    0    0    4    4  100.0        8        5
# 6        2  0.0   0.0  0.0    1    0   48   54   88.9      239       39
# 7        0  0.1   0.1  0.0    1    0   13   16   81.3       22        6
# 8        0  0.0   0.0  0.0    1    0   96  100   96.0      490       79
# 9        0  0.0   0.0  0.0    0    0    5    6   83.3       22        4
# 10       0  0.0   0.0  0.0    1    0   70   81   86.4      485       67
# 11       0  0.0   0.0  0.0    1    0    6    8   75.0       23        7
# 12       2  0.1   0.1  0.0    1    0   68   75   90.7      433       53
# 13       0  0.2   0.2  0.0    2    1   88   89   98.9      456       66
# 14       2  0.0   0.0  0.5    8    0   96  106   90.6      731       80
# 15       0  0.0   0.0  0.0    0    0   30   33   90.9      257       22
# 16       8  2.2   2.2  1.6   37    3  712  791   90.0     3883      622
#
#     PrgDist.1  Succ  Att.1
# 0         360     1      1
# 1         106     1      2
# 2          92     0      1
# 3         117     5      7
# 4         158     1      1
# 5           6     1      1
# 6         148     0      0
# 7          28     0      0
# 8          71     1      2
# 9           0     0      0
# 10        194     0      0
# 11         10     0      0
# 12         99     0      0
# 13        167     0      0
# 14        254     2      4
# 15         25     0      0
# 16       1835    12     19

# %%
prev_df[-1:]
# Out:
#         Player   # Nation  Pos  Age  Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  \
# 16  16 Players NaN    NaN  NaN  NaN  990    2    2   0      0  24    6     3
#
#     CrdR  Touches  Press  Tkl  Int  Blocks   xG  npxG   xA  SCA  GCA  Cmp  \
# 16     0      890    145   25   12       8  2.2   2.2  1.6   37    3  712
#
#     Att  Cmp%  PrgDist  Carries  PrgDist.1  Succ  Att.1
# 16  791  90.0     3883      622       1835    12     19

# %%
vsCagliari = prev_df[-1:].copy
vsCagliari
# Out:
# <bound method NDFrame.copy of         Player   # Nation  Pos  Age  Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  \
# 16  16 Players NaN    NaN  NaN  NaN  990    2    2   0      0  24    6     3
#
#     CrdR  Touches  Press  Tkl  Int  Blocks   xG  npxG   xA  SCA  GCA  Cmp  \
# 16     0      890    145   25   12       8  2.2   2.2  1.6   37    3  712
#
#     Att  Cmp%  PrgDist  Carries  PrgDist.1  Succ  Att.1
# 16  791  90.0     3883      622       1835    12     19  >

# %%
frames = [prev_df[-1:], current_df[-1:]] 
df = pd.concat(frames)
df
# Out:
#         Player   # Nation  Pos  Age  Min  Gls  Ast  PK  PKatt  Sh  SoT  CrdY  \
# 16  16 Players NaN    NaN  NaN  NaN  990    2    2   0      0  24    6     3
# 16  16 Players NaN    NaN  NaN  NaN  990    2    2   0      0  19    6     2
#
#     CrdR  Touches  Press  Tkl  Int  Blocks   xG  npxG   xA  SCA  GCA  Cmp  \
# 16     0      890    145   25   12       8  2.2   2.2  1.6   37    3  712
# 16     0      878    126   16    9      18  1.1   1.1  0.9   30    4  667
#
#     Att  Cmp%  PrgDist  Carries  PrgDist.1  Succ  Att.1
# 16  791  90.0     3883      622       1835    12     19
# 16  774  86.2     3297      633       1579    18     26

# %%
df_sum = df[['Sh', 'SCA', 'Touches', 'PrgDist', 'PrgDist.1', 'Press', 'Tkl', 'Int', 'Blocks']]
df_sum
# Out:
#     Sh  SCA  Touches  PrgDist  PrgDist.1  Press  Tkl  Int  Blocks
# 16  24   37      890     3883       1835    145   25   12       8
# 16  19   30      878     3297       1579    126   16    9      18

# %%
df_trans = df_sum.T # or df1.transpose()

df_trans
# Out:
#              16    16
# Sh           24    19
# SCA          37    30
# Touches     890   878
# PrgDist    3883  3297
# PrgDist.1  1835  1579
# Press       145   126
# Tkl          25    16
# Int          12     9
# Blocks        8    18

# %%
df_sum_copy = df_sum.copy()
df_sum_copy = df_sum_copy.astype(float).round(2)
df_sum_copy
# Out:
#       Sh   SCA  Touches  PrgDist  PrgDist.1  Press   Tkl   Int  Blocks
# 16  24.0  37.0    890.0   3883.0     1835.0  145.0  25.0  12.0     8.0
# 16  19.0  30.0    878.0   3297.0     1579.0  126.0  16.0   9.0    18.0

# %%
for key, val in enumerate(df_sum_copy):
    df_sum_copy[f'{val}'] = df_sum_copy[f'{val}']/df_sum_copy[f'{val}'].max()

df_sum_copy = df_sum_copy.round(2)
df_sum_copy
# Out:
#       Sh   SCA  Touches  PrgDist  PrgDist.1  Press   Tkl   Int  Blocks
# 16  1.00  1.00     1.00     1.00       1.00   1.00  1.00  1.00    0.44
# 16  0.79  0.81     0.99     0.85       0.86   0.87  0.64  0.75    1.00

# %%
# number of variable
categories=list(df_sum_copy)
N = len(categories)
categories
# Out:
# ['Sh',
#  'SCA',
#  'Touches',
#  'PrgDist',
#  'PrgDist.1',
#  'Press',
#  'Tkl',
#  'Int',
#  'Blocks']

# %%
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
 # Draw ylabels
ax.set_rlabel_position(0)  
plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
plt.ylim(0,1)
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df_sum_copy.iloc[0].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="vs Cagliare")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df_sum_copy.iloc[1].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="vs Fener")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
