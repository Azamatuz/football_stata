# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)
from math import pi

# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('vsBene.csv', header=1)
df
# Out:
#                                          Player     #   Nation   Pos     Age  \
# 0                   Álvaro Morata\Alvaro-Morata   9.0   es ESP    FW  28-036
# 1                     Paulo Dybala\Paulo-Dybala  10.0   ar ARG    FW  27-013
# 2                     Aaron Ramsey\Aaron-Ramsey   8.0  wal WAL    LM  29-338
# 3             Dejan Kulusevski\Dejan-Kulusevski  44.0   se SWE    FW  20-217
# 4                   Adrien Rabiot\Adrien-Rabiot  25.0   fr FRA    CM  25-239
# 5                       Arthur Melo\Arthur-Melo   5.0   br BRA    CM  24-108
# 6           Rodrigo Bentancur\Rodrigo-Bentancur  30.0   uy URU    MF  23-176
# 7               Federico Chiesa\Federico-Chiesa  22.0   it ITA    RM  23-034
# 8   Federico Bernardeschi\Federico-Bernardeschi  33.0   it ITA  FWMF  26-286
# 9           Gianluca Frabotta\Gianluca-Frabotta  38.0   it ITA    LB  21-157
# 10                                Danilo\Danilo  13.0   br BRA    CB  29-136
# ...

# %%
for key, name in enumerate(df.Player):
    if '-' in name:
        splitting = name.split('-')
        df.Player[key] = splitting[1]
    else: 
        df.Player[key] = name
df
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/azamat/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            Player     #   Nation   Pos     Age  Min  Gls  Ast  PK  PKatt  Sh  \
# 0          Morata   9.0   es ESP    FW  28-036   89    1    0   0      0   4
# 1          Dybala  10.0   ar ARG    FW  27-013   90    0    0   0      0   6
# 2          Ramsey   8.0  wal WAL    LM  29-338   61    0    0   0      0   1
# ...

# %%
frames = [df[8:9], df[3:4]] 
df = pd.concat(frames)
df
# Out:
#          Player     #  Nation   Pos     Age  Min  Gls  Ast  PK  PKatt  Sh  \
# 8  Bernardeschi  33.0  it ITA  FWMF  26-286   22    0    0   0      0   0
# 3    Kulusevski  44.0  se SWE    FW  20-217   29    0    0   0      0   1
#
#    SoT  CrdY  CrdR  Touches  Press  Tkl  Int  Blocks   xG  npxG   xA  SCA  \
# 8    0     0     0       14      5    0    0       1  0.0   0.0  0.2    3
# 3    1     0     0       18      8    1    0       0  0.0   0.0  0.3    2
#
#    GCA  Cmp  Att  Cmp%  PrgDist  Carries  PrgDist.1  Succ  Att.1
# 8    0    7   13  53.8       29       10         25     0      0
# 3    0    9   13  69.2       21       15        105     0      0

# %%
df_sum = df[['Player','Sh', 'SCA', 'Touches','Att', 'PrgDist', 'Carries','PrgDist.1', 'Press', 'Tkl', 'Int', 'Blocks']]
df_sum
# Out:
#          Player  Sh  SCA  Touches  Att  PrgDist  Carries  PrgDist.1  Press  \
# 8  Bernardeschi   0    3       14   13       29       10         25      5
# 3    Kulusevski   1    2       18   13       21       15        105      8
#
#    Tkl  Int  Blocks
# 8    0    0       1
# 3    1    0       0

# %%
df_sum.columns = ['Player', 'Shots', 'SCA', 'Touches', 'Pass', 'PassPrgDist','Carries', 'CarryPrgDist', 'Press', 'Tackled', 'Interceptions', 'Blocks']
df_sum = df_sum.set_index('Player')

# %%
df_trans = df_sum.T # or df1.transpose()

df_trans
# Out:
# Player         Bernardeschi  Kulusevski
# Shots                     0           1
# SCA                       3           2
# Touches                  14          18
# Pass                     13          13
# PassPrgDist              29          21
# Carries                  10          15
# CarryPrgDist             25         105
# Press                     5           8
# Tackled                   0           1
# Interceptions             0           0
# Blocks                    1           0

# %%
df_sum_copy = df_sum.copy()
df_sum_copy = df_sum_copy.astype(float).round(2)
df_sum_copy
# Out:
#               Shots  SCA  Touches  Pass  PassPrgDist  Carries  CarryPrgDist  \
# Player
# Bernardeschi    0.0  3.0     14.0  13.0         29.0     10.0          25.0
# Kulusevski      1.0  2.0     18.0  13.0         21.0     15.0         105.0
#
#               Press  Tackled  Interceptions  Blocks
# Player
# Bernardeschi    5.0      0.0            0.0     1.0
# Kulusevski      8.0      1.0            0.0     0.0

# %%
df_sum_copy.index[1]
# Out:
# 'Kulusevski'

# %%
for key, val in enumerate(df_sum_copy):
    df_sum_copy[f'{val}'] = df_sum_copy[f'{val}']/df_sum_copy[f'{val}'].max()

df_sum_copy = df_sum_copy.round(2)
df_sum_copy
# Out:
#               Shots   SCA  Touches  Pass  PassPrgDist  Carries  CarryPrgDist  \
# Player
# Bernardeschi    0.0  1.00     0.78   1.0         1.00     0.67          0.24
# Kulusevski      1.0  0.67     1.00   1.0         0.72     1.00          1.00
#
#               Press  Tackled  Interceptions  Blocks
# Player
# Bernardeschi   0.62      0.0            NaN     1.0
# Kulusevski     1.00      1.0            NaN     0.0

# %%
# number of variable
categories=list(df_sum_copy)
N = len(categories)
categories
# Out:
# ['Shots',
#  'SCA',
#  'Touches',
#  'Pass',
#  'PassPrgDist',
#  'Carries',
#  'CarryPrgDist',
#  'Press',
#  'Tackled',
#  'Interceptions',
#  'Blocks']

# %%
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
 # Draw ylabels
ax.set_rlabel_position(0)  
plt.yticks([.25, .5, .75], [".35",".50",".75"], color="grey", size=7)
plt.ylim(0,1)
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df_sum_copy.iloc[0].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=df_sum_copy.index[0])
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df_sum_copy.iloc[1].values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label=df_sum_copy.index[1])
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.savefig((str(df_sum_copy.index[0] + 'VS' + df_sum_copy.index[1]) + ".png"))
# Out:
# /home/azamat/anaconda3/lib/python3.7/site-packages/matplotlib/projections/polar.py:55: RuntimeWarning: invalid value encountered in greater_equal
#   r = np.where(r >= 0, r, np.nan)
