# %%
# Import charting libraries
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", size=14)
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'# Color Themes
color_bg = '#FEF1E5'
darker_highlight = '#FBEADC'
lighter_highlight = '#ffffff'

sns.palplot(sns.color_palette('deep'))


# Import data managment libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
## Imoprt function 
#from data_uploader_from_csv.ipynb import data_uploader
pd.set_option('display.max_columns', None)
# %matplotlib inline
sns.set()

# %%
# Font Imports

import matplotlib.font_manager as fm
heading_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/PlayfairDisplay-Regular.ttf', size=28)
subtitle_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/Roboto-Regular.ttf', size=18)
lable_font = fm.FontProperties(fname='/home/azamat/dev/jupyter/football_stata/Roboto-Regular.ttf', size=20)

fontdict={'fontsize': 24,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

sns.set_context("poster", font_scale=0.8)

# %%
import pandas as pd
df_phys = pd.read_clipboard()

# %%
df_phys
# Out:
#    age  hight  weight       name
# 0   34    193      85      Džeko
# 1   20    194      87     Håland
# 2   32    184      87    Higuaín
# 3   34    190      85  Mandžukić
# 4   26    186      78      Milik
# 5   33    182      85     Suárez

# %%
plt.figure(figsize=(15,5))

x = df_phys['weight']
y = df_phys['hight']
labels = df_phys['name']

ax = sns.scatterplot(x=x, y=y, size=df_phys['age'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of FW\'s physique (height/weight)', fontproperties=heading_font, color="black",      
          position=(.28, 1.02))

plt.ylabel('Weight', fontproperties=lable_font)
plt.xlabel('Height', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_time = pd.read_clipboard()
df_time
# Out:
#         name  MP   Min  Min/90
# 0      Džeko  35  2854      82
# 1     Håland  29  2043      70
# 2    Higuaín  32  1866      58
# 3  Mandžukić  25  2014      81
# 4      Milik  26  1747      67
# 5     Suárez  28  1998      71

# %%
plt.figure(figsize=(15,5))

x = df_time['MP']
y = df_time['Min']
labels = df_time['name']

ax = sns.scatterplot(x=x, y=y, size=df_time['Min/90'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of time played (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.38, 1.02))
#plt.text(x=-.8, y=97, s='All competiotions (2019/2020)',fontproperties=subtitle_font,color='#524939')

#plt.text(x=2.5, y=-6, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('Minuts Played', fontproperties=lable_font)
plt.xlabel('Matches Played', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_gls = pd.read_clipboard()
df_gls
# Out:
#         name  Gls  Ast  Gls/90
# 0      Džeko   16    7    0.46
# 1     Håland   29    6    1.00
# 2    Higuaín    8    4    0.25
# 3  Mandžukić    9    6    0.36
# 4      Milik   11    0    0.42
# 5     Suárez   16    8    0.57

# %%
plt.figure(figsize=(15,5))

x = df_gls['Gls']
y = df_gls['Ast']
labels = df_gls['name']

ax = sns.scatterplot(x=x, y=y, size=df_gls['Gls/90'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of goals scored and assists (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.46, 1.02))
#plt.text(x=-.8, y=97, s='All competiotions (2019/2020)',fontproperties=subtitle_font,color='#524939')

#plt.text(x=2.5, y=-6, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('Assists', fontproperties=lable_font)
plt.xlabel('Goals', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_xg = pd.read_clipboard()
df_xg
# Out:
#         name    xG   xA  Gls-xG  Ast-xA  xG+xA/90
# 0      Džeko  18.1  5.0    -2.1     2.0      0.66
# 1     Håland   8.1  1.6    20.9     4.4      0.33
# 2    Higuaín   9.5  4.3    -1.5    -0.3      0.43
# 3  Mandžukić   4.9  2.6     4.1     3.4      0.30
# 4      Milik  10.2  2.1     0.8    -2.1      0.47
# 5     Suárez  13.9  3.7     2.1     4.3      0.63

# %%
plt.figure(figsize=(15,5))

x = df_xg['xG']
y = df_xg['xA']
labels = df_xg['name']

ax = sns.scatterplot(x=x, y=y, size=df_xg['Gls-xG'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of expected goals(xG) and assists(xA) (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.46, 1.02))
#plt.text(x=-.8, y=97, s='All competiotions (2019/2020)',fontproperties=subtitle_font,color='#524939')

#plt.text(x=2.5, y=-6, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Expected Goals', fontproperties=lable_font)
plt.ylabel('Expected Assists', fontproperties=lable_font)
sns.despine(left=True)

# %%
plt.figure(figsize=(15,5))

x = df_xg['xG']
y = df_xg['xA']
labels = df_xg['name']

ax = sns.scatterplot(x=x, y=y, size=df_xg['xG+xA/90'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of expected goals(xG) and assists(xA) (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.46, 1.02))
#plt.text(x=-.8, y=97, s='All competiotions (2019/2020)',fontproperties=subtitle_font,color='#524939')

#plt.text(x=2.5, y=-6, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.xlabel('Expected Goals', fontproperties=lable_font)
plt.ylabel('Expected Assists', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_xg = df_xg.sort_values(by=['Gls-xG'], ascending=False)
df_xg = df_xg.drop(1)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df_xg['name'], y=df_xg['Gls-xG'], palette="vlag")
plt.title('Comparison of finishing index (Gls - xG), (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.48, 1.05))
plt.text(x=-0.5, y=4.5, s='Excluding Haland',fontproperties=subtitle_font,color='#524939')
plt.ylabel('Difference b/w Gls and xG)', fontproperties=lable_font)
plt.xlabel('', fontproperties=lable_font)
sns.despine(left=True)

# %%
df_xa = df_xg.sort_values(by=['Gls-xG'], ascending=False)

# %%
df_sca = pd.read_clipboard()
df_sca
# Out:
#         name  sca  gca  ra/90
# 0      Džeko  111   18   3.69
# 1     Håland   25    7   1.10
# 2    Higuaín   92    5   3.03
# 3  Mandžukić   50   10   2.40
# 4      Milik   47    6   2.04
# 5     Suárez   73   17   3.21

# %%
plt.figure(figsize=(15,5))

x = df_sca['sca']
y = df_sca['gca']
labels = df_sca['name']

ax = sns.scatterplot(x=x, y=y, size=df_sca['ra/90'])
for x_pos, y_pos, label in zip(x, y, labels):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(7, 0),     # Offset text by 7 points to the right
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered

plt.title('Comparison of goal and shot creation (Domestic, 2019/2020*)', fontproperties=heading_font, color="black",      
          position=(.46, 1.02))
#plt.text(x=-.8, y=97, s='All competiotions (2019/2020)',fontproperties=subtitle_font,color='#524939')

#plt.text(x=2.5, y=-6, s='Data source: fbref.com',fontproperties=subtitle_font, horizontalalignment='right',color='#524939')

plt.ylabel('Goals-Creating Action ', fontproperties=lable_font)
plt.xlabel('Shot-Creating Action', fontproperties=lable_font)
sns.despine(left=True)
